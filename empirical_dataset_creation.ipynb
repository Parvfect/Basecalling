# %%
# First we need to examine the csv file

# %% [markdown]
# ## Creating the empirical dataset from the Helixworks data
#
# Seems like the motif caller identified data is in that excel file, from which we can extract the read ids and use that to get the fast5 data.
# We seem to be limited by the performance of the motif search algorithm, so it would be interesting to compare the performance on unseen data, which is hard to create, but maybe by rerunning the motif search and seeing what we get, or evaluating the motif caller on stuff its not trained on to see if it identifies anything new.
# Given the base error problem with motif calling, this should be the case, let us see if we can prove it though.

# %% [markdown]
# ### Examining the motif sequences from the result of motif calling

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Parv\Doc\HelixWorks\Basecalling\data\helixworks_1280_fast5_2024-02-09_1638\motif_search_barcoded.csv")

# %%
def library_motif_segregation():
    library_motifs = df['library_motif'].to_numpy()
    library_motifs_arr = []
    no_motifs = []
    for i in library_motifs:
        motifs_arr = i.split('|')
        library_motifs_arr.append(motifs_arr)
        no_motifs.append(len(motifs_arr))
    return library_motifs_arr, no_motifs


library_motifs_arr, motifs_discovered = library_motif_segregation()
df['library_motifs_arr'] = library_motifs_arr
df['motifs_discovered'] = motifs_discovered


df['ONT_Barcode'] = df['ONT_Barcode'].apply(lambda x: int(x[-2:]))
df.head()
# Out:
#                                 read_id  ONT_Barcode  \
# 0  0117ec74-7ef1-4e8c-b169-c8ca9a576de4            1
# 1  01575c8a-4a38-4554-9d88-5acbc61059a4            1
# 2  01ecbbe8-550d-433b-a2af-354c33c91dde            1
# 3  062cd1bc-9132-4144-bd56-5aea4e9a5529            1
# 4  06382a54-201e-46cf-beeb-c8d574b30e85            1
#
#                       HW_Address orientation  \
# 0  barcode_external01_internal01       +|+|+
# 1  barcode_external01_internal01         +|+
# 2  barcode_external01_internal01           +
# 3  barcode_external01_internal01     +|+|+|+
# 4  barcode_external01_internal01   +|+|+|+|+
#
#                                  start_end  \
# 0                   75-124|370-419|566-615
# 1                          176-225|275-324
# 2                                  108-157
# 3          154-203|251-300|301-350|351-400
# 4  149-198|199-248|299-348|349-398|497-546
#
#                                   library_motif  \
# 0                    ltm8_2x1|ltm8_5x4|ltm8_9x1
# 1                             ltm8_6x1|ltm8_8x7
# 2                                      ltm8_1x1
# 3           ltm8_2x1|ltm8_4x2|ltm8_5x5|ltm8_6x4
# 4  ltm8_2x1|ltm8_3x4|ltm8_5x5|ltm8_6x8|ltm8_9x3
#
#                                   library_motifs_arr  motifs_discovered
# 0                     [ltm8_2x1, ltm8_5x4, ltm8_9x1]                  3
# 1                               [ltm8_6x1, ltm8_8x7]                  2
# 2                                         [ltm8_1x1]                  1
# 3           [ltm8_2x1, ltm8_4x2, ltm8_5x5, ltm8_6x4]                  4
# 4  [ltm8_2x1, ltm8_3x4, ltm8_5x5, ltm8_6x8, ltm8_...                  5

# %% [markdown]
# ## Encoded csv

# %%
import re

encoded_file_path = r"C:\Users\Parv\Doc\HelixWorks\Basecalling\data\helixworks_1280_fast5_2024-02-09_1638\EIC01-01-1280-T1_encoded.tsv"


with open(encoded_file_path, 'r') as f:
    lines = f.readlines()

lines = [line.strip() for line in lines]

ONT_barcodes = []
HW_addresses = []
cycles = []
payloads = []

for i, line in enumerate(lines):
    if i==0:
        continue

    ONT_barcodes.append(int(line[:2]))

    matches = re.findall(r'"(.*?)"', line)
    
    local_payload = []
    for j, match in enumerate(matches):
        if j == 0:
            HW_addresses.append(match)
        else:
            local_payload.append(eval(match))

    payloads.append(local_payload)
    

encoded_df = pd.DataFrame({'ONT_Barcode': ONT_barcodes, 'HW_Address': HW_addresses, 'Payload': payloads})

# %% [markdown]
# ## Creating dataset

# %%
import numpy as np
ont_barcodes = np.arange(1,77, 4)
test_barcodes = [5, 29, 53]
train_barcodes = [barcode for barcode in ont_barcodes if barcode not in test_barcodes]

# %%
encoded_train_df = encoded_df[encoded_df['ONT_Barcode'].isin(train_barcodes)]
encoded_test_df = encoded_df[encoded_df['ONT_Barcode'].isin(test_barcodes)]

# %%
train_barcodes
# Out:
# [np.int64(1),
#  np.int64(9),
#  np.int64(13),
#  np.int64(17),
#  np.int64(21),
#  np.int64(25),
#  np.int64(33),
#  np.int64(37),
#  np.int64(41),
#  np.int64(45),
#  np.int64(49),
#  np.int64(57),
#  np.int64(61),
#  np.int64(65),
#  np.int64(69),
#  np.int64(73)]

# %%
import matplotlib.pyplot as plt
from tqdm import tqdm
# for each barcode and hw address that uniquely define a cycle - select best quality of reads 

def get_best_quality_reads(ont_barcode, hw_address):

    df_subset = df[(df['ONT_Barcode'] == ont_barcode) & (df['HW_Address'] == hw_address) & (df['motifs_discovered'] > 6)]

    read_ids = df_subset['read_id'].to_numpy()
    library_motifs_arr = df_subset['library_motifs_arr'].to_numpy()
    return read_ids, library_motifs_arr



# Iterating over all the barcodes and hw addresses to get the best quality reads and their corresponding read ids
training_arr = []
for barcode in tqdm(train_barcodes):
    for hw_address in tqdm(encoded_df['HW_Address'].unique()):
        read_ids, library_motifs_arr = get_best_quality_reads(barcode, hw_address)
        payload = encoded_train_df[(encoded_train_df['ONT_Barcode'] == barcode) & (
            encoded_train_df['HW_Address'] == hw_address)]['Payload'].to_numpy()[0]
        for i, read_id in enumerate(read_ids):
            training_arr.append([
                barcode, hw_address, payload, library_motifs_arr[i], read_id])
# Out:
# 100%|██████████| 64/64 [00:02<00:00, 25.19it/s]
#  27%|██▋       | 17/64 [00:00<00:01, 27.06it/s]
#   6%|▋         | 1/16 [00:03<00:47,  3.18s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 19
#      17 for barcode in tqdm(train_barcodes):
#      18     for hw_address in tqdm(encoded_df['HW_Address'].unique()):
# ---> 19         read_ids, library_motifs_arr = get_best_quality_reads(barcode, hw_address)
#      20         payload = encoded_train_df[(encoded_train_df['ONT_Barcode'] == barcode) & (
#      21             encoded_train_df['HW_Address'] == hw_address)]['Payload'].to_numpy()[0]
#      22         for i, read_id in enumerate(read_ids):
#
# Cell In[8], line 7, in get_best_quality_reads(ont_barcode, hw_address)
#       5 def get_best_quality_reads(ont_barcode, hw_address):
# ----> 7     df_subset = df[(df['ONT_Barcode'] == ont_barcode) & (df['HW_Address'] == hw_address) & (df['motifs_discovered'] > 6)]
#       9     read_ids = df_subset['read_id'].to_numpy()
#      10     library_motifs_arr = df_subset['library_motifs_arr'].to_numpy()
#
# File c:\Users\Parv\Doc\HelixWorks\Basecalling\code\cluster_basecalling\env\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\Parv\Doc\HelixWorks\Basecalling\code\cluster_basecalling\env\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\Parv\Doc\HelixWorks\Basecalling\code\cluster_basecalling\env\lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\Parv\Doc\HelixWorks\Basecalling\code\cluster_basecalling\env\lib\site-packages\pandas\core\ops\array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Users\Parv\Doc\HelixWorks\Basecalling\code\cluster_basecalling\env\lib\site-packages\pandas\core\ops\array_ops.py:130, in comp_method_OBJECT_ARRAY(op, x, y)
#     128 else:
#     129     result = libops.scalar_compare(x.ravel(), y, op)
# --> 130 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
empirical_train_df = pd.DataFrame(training_arr, columns=['ONT_Barcode', 'HW_Address', 'Payload', 'Library_Motifs', 'read_id'])

# %%
empirical_train_df.head()
# Out:
#    ONT_Barcode                     HW_Address  \
# 0            1  barcode_external01_internal01
# 1            1  barcode_external01_internal01
# 2            1  barcode_external01_internal01
# 3            1  barcode_external01_internal01
# 4            1  barcode_external01_internal01
#
#                                              Payload  \
# 0  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 1  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 2  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 3  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 4  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
#
#                                       Library_Motifs  \
# 0  [ltm8_2x1, ltm8_3x3, ltm8_3x5, ltm8_4x1, ltm8_...
# 1  [ltm8_3x5, ltm8_4x1, ltm8_4x1, ltm8_6x7, ltm8_...
# 2  [ltm8_1x1, ltm8_2x1, ltm8_4x2, ltm8_5x7, ltm8_...
# 3  [ltm8_1x1, ltm8_2x1, ltm8_2x1, ltm8_3x4, ltm8_...
# 4  [ltm8_1x1, ltm8_3x2, ltm8_4x2, ltm8_5x1, ltm8_...
#
#                                 read_id
# 0  0804c886-cd0a-4ece-87ee-adb529974699
# 1  0f041c54-7071-49d3-8ae2-7a1bf25525ab
# 2  1361a5db-d135-4e98-bb49-7a53c8d72991
# 3  1b4284d2-bee2-4a15-abab-aad861447308
# 4  1cc7b7bb-cd90-485f-b744-cf846d566675

# %%
test_arr = []
for barcode in test_barcodes:
    for hw_address in encoded_df['HW_Address'].unique():
        read_ids, library_motifs_arr = get_best_quality_reads(barcode, hw_address)
        payload = encoded_test_df[(encoded_test_df['ONT_Barcode'] == barcode) & (
            encoded_test_df['HW_Address'] == hw_address)]['Payload'].to_numpy()[0]
        for i, read_id in enumerate(read_ids):
            test_arr.append([
                barcode, hw_address, payload, library_motifs_arr[i], read_id])

# %%
empirical_test_df = pd.DataFrame(test_arr, columns=['ONT_Barcode', 'HW_Address', 'Payload', 'Library_Motifs', 'read_id'])

# %%
empirical_test_df.head()
# Out:
#    ONT_Barcode                     HW_Address  \
# 0            5  barcode_external01_internal01
# 1            5  barcode_external01_internal01
# 2            5  barcode_external01_internal01
# 3            5  barcode_external01_internal01
# 4            5  barcode_external01_internal01
#
#                                              Payload  \
# 0  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 1  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 2  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 3  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 4  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
#
#                                       Library_Motifs  \
# 0  [ltm8_2x1, ltm8_3x8, ltm8_4x4, ltm8_5x1, ltm8_...
# 1  [ltm8_1x1, ltm8_2x1, ltm8_3x7, ltm8_4x8, ltm8_...
# 2  [ltm8_2x1, ltm8_3x6, ltm8_5x6, ltm8_6x5, ltm8_...
# 3  [ltm8_1x1, ltm8_3x3, ltm8_4x5, ltm8_5x1, ltm8_...
# 4  [ltm8_2x1, ltm8_3x3, ltm8_4x4, ltm8_5x4, ltm8_...
#
#                                 read_id
# 0  0038e7e2-ab7a-4e8e-a9b5-d39eefa8b0f2
# 1  017a284c-952d-422e-ba1a-c4d88e06a3ac
# 2  03022dc4-6086-481a-bb42-c935846ab94c
# 3  1a7bac06-9b7b-4cb5-88f2-bdfc19772c4e
# 4  2c9c7e7b-51b6-468b-a3cf-75e48085c59f

# %%
empirical_train_df.to_csv("datasets\empirical\paper\empirical_train_read_ids.csv", index=False)
encoded_test_df.to_csv("datasets\empirical\paper\empirical_test_read_ids.csv", index=False)

# %%
target_read_ids_train = empirical_train_df['read_id'].to_numpy().tolist()
target_read_ids_test = empirical_test_df['read_id'].to_numpy().tolist()

# %%
total_read_ids = target_read_ids_train + target_read_ids_test
len(total_read_ids)
# Out:
# 28046

# %% [markdown]
# ## Extracting the fast5 from the files

# %%
# Loading the read id dataframes
import pandas as pd

empirical_train_df_loaded = pd.read_csv("datasets\empirical\paper\empirical_train_read_ids.csv")
empirical_test_df_loaded = pd.read_csv("datasets\empirical\paper\empirical_test_read_ids.csv")
empirical_train_df_loaded.head()
# Out:
#    ONT_Barcode                     HW_Address  \
# 0            1  barcode_external01_internal01
# 1            1  barcode_external01_internal01
# 2            1  barcode_external01_internal01
# 3            1  barcode_external01_internal01
# 4            1  barcode_external01_internal01
#
#                                              Payload  \
# 0  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 1  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 2  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 3  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 4  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
#
#                                       Library_Motifs  \
# 0  ['ltm8_2x1', 'ltm8_3x3', 'ltm8_3x5', 'ltm8_4x1...
# 1  ['ltm8_3x5', 'ltm8_4x1', 'ltm8_4x1', 'ltm8_6x7...
# 2  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_4x2', 'ltm8_5x7...
# 3  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_2x1', 'ltm8_3x4...
# 4  ['ltm8_1x1', 'ltm8_3x2', 'ltm8_4x2', 'ltm8_5x1...
#
#                                 read_id
# 0  0804c886-cd0a-4ece-87ee-adb529974699
# 1  0f041c54-7071-49d3-8ae2-7a1bf25525ab
# 2  1361a5db-d135-4e98-bb49-7a53c8d72991
# 3  1b4284d2-bee2-4a15-abab-aad861447308
# 4  1cc7b7bb-cd90-485f-b744-cf846d566675

# %%
target_read_ids_train = empirical_train_df_loaded['read_id'].to_numpy().tolist()
target_read_ids_test = empirical_test_df['read_id'].to_numpy().tolist()
total_read_ids = target_read_ids_train
len(total_read_ids)
# Out:
# 23939

# %%
import numpy as np

# Adding placeholder for squiggle
#empirical_train_df_loaded['squiggle'] = [np.zeros(3) for _ in range(empirical_train_df_loaded.shape[0])]
empirical_test_df['squiggle'] = [np.zeros(3) for _ in range(empirical_test_df.shape[0])]

# %%
empirical_train_df_loaded.head()
# Out:
#    ONT_Barcode                     HW_Address  \
# 0            1  barcode_external01_internal01
# 1            1  barcode_external01_internal01
# 2            1  barcode_external01_internal01
# 3            1  barcode_external01_internal01
# 4            1  barcode_external01_internal01
#
#                                              Payload  \
# 0  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 1  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 2  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 3  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 4  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
#
#                                       Library_Motifs  \
# 0  ['ltm8_2x1', 'ltm8_3x3', 'ltm8_3x5', 'ltm8_4x1...
# 1  ['ltm8_3x5', 'ltm8_4x1', 'ltm8_4x1', 'ltm8_6x7...
# 2  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_4x2', 'ltm8_5x7...
# 3  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_2x1', 'ltm8_3x4...
# 4  ['ltm8_1x1', 'ltm8_3x2', 'ltm8_4x2', 'ltm8_5x1...
#
#                                 read_id         squiggle
# 0  0804c886-cd0a-4ece-87ee-adb529974699  [0.0, 0.0, 0.0]
# 1  0f041c54-7071-49d3-8ae2-7a1bf25525ab  [0.0, 0.0, 0.0]
# 2  1361a5db-d135-4e98-bb49-7a53c8d72991  [0.0, 0.0, 0.0]
# 3  1b4284d2-bee2-4a15-abab-aad861447308  [0.0, 0.0, 0.0]
# 4  1cc7b7bb-cd90-485f-b744-cf846d566675  [0.0, 0.0, 0.0]

# %%
import os
from ont_fast5_api.fast5_interface import get_fast5_file

fast5_path = r"C:\Users\Parv\Doc\HelixWorks\Basecalling\data\helixworks_1280_fast5_2024-02-09_1638\1280_FAST5"

total_files = len(os.listdir(fast5_path))
file_number = 0
read_ids_found = []

squiggles = {}

# Trying to see if I can get 10 percent of the reads and have some form of a database
for file in os.listdir(fast5_path):
    file_number+=1

    # Printing the progress
    if file_number % 10 == 0:
        print(file_number/total_files)

    filepath = os.path.join(fast5_path, file)
    with get_fast5_file(filepath, mode="r") as f5:
        read_ids = f5.get_read_ids()
        read_ids = list(set(read_ids).intersection(target_read_ids_test))

        for read_id in read_ids:
            read = f5.get_read(read_id)
            squiggle = read.get_raw_data()
            squiggles[read_id] = squiggle
# Out:
# 0.013966480446927373
# 0.027932960893854747
# 0.04189944134078212
# 0.055865921787709494
# 0.06983240223463687
# 0.08379888268156424
# 0.09776536312849161
# 0.11173184357541899
# 0.12569832402234637
# 0.13966480446927373
# 0.15363128491620112
# 0.16759776536312848
# 0.18156424581005587
# 0.19553072625698323
# 0.20949720670391062
# 0.22346368715083798
# 0.23743016759776536
# 0.25139664804469275
# 0.26536312849162014
# 0.27932960893854747
# 0.29329608938547486
# 0.30726256983240224
# 0.32122905027932963
# 0.33519553072625696
# 0.34916201117318435
# 0.36312849162011174
# 0.3770949720670391
# 0.39106145251396646
# 0.40502793296089384
# 0.41899441340782123
# 0.4329608938547486
# 0.44692737430167595
# 0.46089385474860334
# 0.4748603351955307
# 0.4888268156424581
# 0.5027932960893855
# 0.5167597765363129
# 0.5307262569832403
# 0.5446927374301676
# 0.5586592178770949
# 0.5726256983240223
# 0.5865921787709497
# 0.6005586592178771
# 0.6145251396648045
# 0.6284916201117319
# 0.6424581005586593
# 0.6564245810055865
# 0.6703910614525139
# 0.6843575418994413
# 0.6983240223463687
# 0.7122905027932961
# 0.7262569832402235
# 0.7402234636871509
# 0.7541899441340782
# 0.7681564245810056
# 0.7821229050279329
# 0.7960893854748603
# 0.8100558659217877
# 0.8240223463687151
# 0.8379888268156425
# 0.8519553072625698
# 0.8659217877094972
# 0.8798882681564246
# 0.8938547486033519
# 0.9078212290502793
# 0.9217877094972067
# 0.9357541899441341
# 0.9497206703910615
# 0.9636871508379888
# 0.9776536312849162
# 0.9916201117318436

# %%
# seperate the squiggles into train and test squiggles
#train_squiggles = {k:squiggles[k] for k in squiggles.keys() if k in target_read_ids_train}
test_squiggles = {k:squiggles[k] for k in squiggles.keys() if k in target_read_ids_test}

# %%
len(train_squiggles)#, len(test_squiggles)
# Out:
# 23391

# %%
len(test_squiggles)
# Out:
# 4012

# %%
# get subset of dataframe with only those read ids
#empirical_train_df_subset = empirical_train_df_loaded[empirical_train_df_loaded['read_id'].isin(train_squiggles.keys())]
empirical_test_df_subset = empirical_test_df[empirical_test_df['read_id'].isin(test_squiggles.keys())]

# %%
# Add the squiggles to the dataframe - matching by the read id
#empirical_train_df_subset['squiggle'] = empirical_train_df_subset['read_id'].apply(lambda x: train_squiggles[x])
empirical_test_df_subset['squiggle'] = empirical_test_df_subset['read_id'].apply(lambda x: test_squiggles[x])
# Out:
# C:\Users\Parv\AppData\Local\Temp\ipykernel_34608\3483524833.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empirical_test_df_subset['squiggle'] = empirical_test_df_subset['read_id'].apply(lambda x: test_squiggles[x])

# %%
len(empirical_train_df_subset['squiggle'][2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 len(empirical_train_df_subset['squiggle'][2])
#
# NameError: name 'empirical_train_df_subset' is not defined

# %%
empirical_train_df_subset.head()
# Out:
#    ONT_Barcode                     HW_Address  \
# 0            1  barcode_external01_internal01
# 1            1  barcode_external01_internal01
# 2            1  barcode_external01_internal01
# 3            1  barcode_external01_internal01
# 4            1  barcode_external01_internal01
#
#                                              Payload  \
# 0  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 1  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 2  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 3  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 4  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
#
#                                       Library_Motifs  \
# 0  ['ltm8_2x1', 'ltm8_3x3', 'ltm8_3x5', 'ltm8_4x1...
# 1  ['ltm8_3x5', 'ltm8_4x1', 'ltm8_4x1', 'ltm8_6x7...
# 2  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_4x2', 'ltm8_5x7...
# 3  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_2x1', 'ltm8_3x4...
# 4  ['ltm8_1x1', 'ltm8_3x2', 'ltm8_4x2', 'ltm8_5x1...
#
#                                 read_id  \
# 0  0804c886-cd0a-4ece-87ee-adb529974699
# 1  0f041c54-7071-49d3-8ae2-7a1bf25525ab
# 2  1361a5db-d135-4e98-bb49-7a53c8d72991
# 3  1b4284d2-bee2-4a15-abab-aad861447308
# 4  1cc7b7bb-cd90-485f-b744-cf846d566675
#
#                                             squiggle
# 0  [482, 486, 493, 488, 465, 494, 470, 474, 472, ...
# 1  [472, 438, 454, 427, 435, 480, 478, 494, 503, ...
# 2  [671, 498, 504, 526, 502, 512, 527, 528, 517, ...
# 3  [558, 468, 470, 488, 474, 465, 466, 478, 460, ...
# 4  [509, 488, 488, 494, 480, 495, 505, 495, 489, ...

# %%
empirical_test_df_subset.head()
# Out:
#    ONT_Barcode                     HW_Address  \
# 0            5  barcode_external01_internal01
# 1            5  barcode_external01_internal01
# 2            5  barcode_external01_internal01
# 3            5  barcode_external01_internal01
# 4            5  barcode_external01_internal01
#
#                                              Payload  \
# 0  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 1  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 2  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 3  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 4  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
#
#                                       Library_Motifs  \
# 0  [ltm8_2x1, ltm8_3x8, ltm8_4x4, ltm8_5x1, ltm8_...
# 1  [ltm8_1x1, ltm8_2x1, ltm8_3x7, ltm8_4x8, ltm8_...
# 2  [ltm8_2x1, ltm8_3x6, ltm8_5x6, ltm8_6x5, ltm8_...
# 3  [ltm8_1x1, ltm8_3x3, ltm8_4x5, ltm8_5x1, ltm8_...
# 4  [ltm8_2x1, ltm8_3x3, ltm8_4x4, ltm8_5x4, ltm8_...
#
#                                 read_id  \
# 0  0038e7e2-ab7a-4e8e-a9b5-d39eefa8b0f2
# 1  017a284c-952d-422e-ba1a-c4d88e06a3ac
# 2  03022dc4-6086-481a-bb42-c935846ab94c
# 3  1a7bac06-9b7b-4cb5-88f2-bdfc19772c4e
# 4  2c9c7e7b-51b6-468b-a3cf-75e48085c59f
#
#                                             squiggle
# 0  [648, 482, 468, 487, 489, 488, 481, 576, 653, ...
# 1  [511, 555, 550, 521, 679, 684, 682, 659, 669, ...
# 2  [591, 436, 416, 441, 430, 444, 411, 444, 434, ...
# 3  [582, 436, 437, 417, 447, 515, 497, 483, 496, ...
# 4  [597, 422, 436, 442, 439, 432, 438, 428, 449, ...

# %% [markdown]
# Cool - that is guessing cycle position - let us just part into motifs

# %%
Motifs = empirical_train_df_subset['Library_Motifs'].to_numpy()

motifs_updated = []
for motif in Motifs:
    local_motifs = [int(i[-1]) for i in eval(motif)]
    motifs_updated.append(local_motifs)

# %%
empirical_train_df_subset['Motifs'] = motifs_updated
# Out:
# C:\Users\Parv\AppData\Local\Temp\ipykernel_19400\2858394839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empirical_train_df_subset['Motifs'] = motifs_updated

# %%
Motifs = empirical_test_df_subset['Library_Motifs'].to_numpy()

motifs_updated = []
for motif in Motifs:
    local_motifs = [int(i[-1]) for i in motif]
    motifs_updated.append(local_motifs)

empirical_test_df_subset['Motifs'] = motifs_updated
# Out:
# C:\Users\Parv\AppData\Local\Temp\ipykernel_34608\3322629448.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empirical_test_df_subset['Motifs'] = motifs_updated

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# Normalize the squiggle data
empirical_train_df_subset['squiggle'] = empirical_train_df_subset['squiggle'].apply(lambda x: scaler.fit_transform(np.array(x).reshape(-1, 1)).reshape(-1))

empirical_train_df_subset.head()
# Out:
# C:\Users\Parv\AppData\Local\Temp\ipykernel_19400\3926697547.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empirical_train_df_subset['squiggle'] = empirical_train_df_subset['squiggle'].apply(lambda x: scaler.fit_transform(np.array(x).reshape(-1, 1)).reshape(-1))
#    ONT_Barcode                     HW_Address  \
# 0            1  barcode_external01_internal01
# 1            1  barcode_external01_internal01
# 2            1  barcode_external01_internal01
# 3            1  barcode_external01_internal01
# 4            1  barcode_external01_internal01
#
#                                              Payload  \
# 0  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 1  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 2  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 3  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 4  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
#
#                                       Library_Motifs  \
# 0  ['ltm8_2x1', 'ltm8_3x3', 'ltm8_3x5', 'ltm8_4x1...
# 1  ['ltm8_3x5', 'ltm8_4x1', 'ltm8_4x1', 'ltm8_6x7...
# 2  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_4x2', 'ltm8_5x7...
# 3  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_2x1', 'ltm8_3x4...
# 4  ['ltm8_1x1', 'ltm8_3x2', 'ltm8_4x2', 'ltm8_5x1...
#
#                                 read_id  \
# 0  0804c886-cd0a-4ece-87ee-adb529974699
# 1  0f041c54-7071-49d3-8ae2-7a1bf25525ab
# 2  1361a5db-d135-4e98-bb49-7a53c8d72991
# 3  1b4284d2-bee2-4a15-abab-aad861447308
# 4  1cc7b7bb-cd90-485f-b744-cf846d566675
#
#                                             squiggle  \
# 0  [0.7250000000000001, 0.7350000000000001, 0.752...
# 1  [0.525, 0.4845238095238096, 0.5035714285714287...
# 2  [0.6675799086757991, 0.5095890410958903, 0.515...
# 3  [0.6846153846153846, 0.5461538461538461, 0.549...
# 4  [0.7113163972286374, 0.6628175519630484, 0.662...
#
#                         Motifs
# 0        [1, 3, 5, 1, 1, 4, 5]
# 1        [5, 1, 1, 7, 7, 7, 8]
# 2     [1, 1, 2, 7, 4, 5, 6, 5]
# 3        [1, 1, 1, 4, 4, 6, 6]
# 4  [1, 2, 2, 1, 4, 8, 3, 3, 5]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# Normalize the squiggle data
empirical_test_df_subset['squiggle'] = empirical_test_df_subset['squiggle'].apply(lambda x: scaler.fit_transform(np.array(x).reshape(-1, 1)).reshape(-1))

empirical_test_df_subset.head()
# Out:
# C:\Users\Parv\AppData\Local\Temp\ipykernel_34608\2360165347.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empirical_test_df_subset['squiggle'] = empirical_test_df_subset['squiggle'].apply(lambda x: scaler.fit_transform(np.array(x).reshape(-1, 1)).reshape(-1))
#    ONT_Barcode                     HW_Address  \
# 0            5  barcode_external01_internal01
# 1            5  barcode_external01_internal01
# 2            5  barcode_external01_internal01
# 3            5  barcode_external01_internal01
# 4            5  barcode_external01_internal01
#
#                                              Payload  \
# 0  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 1  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 2  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 3  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 4  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
#
#                                       Library_Motifs  \
# 0  [ltm8_2x1, ltm8_3x8, ltm8_4x4, ltm8_5x1, ltm8_...
# 1  [ltm8_1x1, ltm8_2x1, ltm8_3x7, ltm8_4x8, ltm8_...
# 2  [ltm8_2x1, ltm8_3x6, ltm8_5x6, ltm8_6x5, ltm8_...
# 3  [ltm8_1x1, ltm8_3x3, ltm8_4x5, ltm8_5x1, ltm8_...
# 4  [ltm8_2x1, ltm8_3x3, ltm8_4x4, ltm8_5x4, ltm8_...
#
#                                 read_id  \
# 0  0038e7e2-ab7a-4e8e-a9b5-d39eefa8b0f2
# 1  017a284c-952d-422e-ba1a-c4d88e06a3ac
# 2  03022dc4-6086-481a-bb42-c935846ab94c
# 3  1a7bac06-9b7b-4cb5-88f2-bdfc19772c4e
# 4  2c9c7e7b-51b6-468b-a3cf-75e48085c59f
#
#                                             squiggle                 Motifs
# 0  [0.5791722622390428, 0.5589061164692956, 0.557...  [1, 8, 4, 1, 8, 8, 4]
# 1  [0.694006309148265, 0.7634069400630915, 0.7555...  [1, 1, 7, 8, 4, 4, 7]
# 2  [0.7538994800693242, 0.48526863084922006, 0.45...  [1, 6, 6, 5, 8, 4, 5]
# 3  [0.5326492537313433, 0.396455223880597, 0.3973...  [1, 3, 5, 1, 6, 7, 1]
# 4  [0.5729459162495422, 0.5515810035404712, 0.553...  [1, 3, 4, 4, 2, 4, 3]

# %%
squiggles = empirical_test_df_subset['squiggle'].to_numpy()
print(len(squiggles[3]))
# Out:
# 8400

# %%
empirical_test

# %%
empirical_test_df_subset.to_pickle("empirical_test_dataset_v3.pkl")

# %% [markdown]
# ### Loading and checking integrity of the saved data

# %%
empirical_test = pd.read_pickle("empirical_test_dataset_v3.pkl")

#pd.read_csv("empirical_train_dataset_v3.csv")

# %%
empirical_test.head()
# Out:
#    ONT_Barcode                     HW_Address  \
# 0            5  barcode_external01_internal01
# 1            5  barcode_external01_internal01
# 2            5  barcode_external01_internal01
# 3            5  barcode_external01_internal01
# 4            5  barcode_external01_internal01
#
#                                              Payload  \
# 0  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 1  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 2  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 3  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
# 4  [[3, 6, 7, 8], [3, 4, 5, 8], [1, 2, 4, 6], [1,...
#
#                                       Library_Motifs  \
# 0  [ltm8_2x1, ltm8_3x8, ltm8_4x4, ltm8_5x1, ltm8_...
# 1  [ltm8_1x1, ltm8_2x1, ltm8_3x7, ltm8_4x8, ltm8_...
# 2  [ltm8_2x1, ltm8_3x6, ltm8_5x6, ltm8_6x5, ltm8_...
# 3  [ltm8_1x1, ltm8_3x3, ltm8_4x5, ltm8_5x1, ltm8_...
# 4  [ltm8_2x1, ltm8_3x3, ltm8_4x4, ltm8_5x4, ltm8_...
#
#                                 read_id  \
# 0  0038e7e2-ab7a-4e8e-a9b5-d39eefa8b0f2
# 1  017a284c-952d-422e-ba1a-c4d88e06a3ac
# 2  03022dc4-6086-481a-bb42-c935846ab94c
# 3  1a7bac06-9b7b-4cb5-88f2-bdfc19772c4e
# 4  2c9c7e7b-51b6-468b-a3cf-75e48085c59f
#
#                                             squiggle                 Motifs
# 0  [0.5791722622390428, 0.5589061164692956, 0.557...  [1, 8, 4, 1, 8, 8, 4]
# 1  [0.694006309148265, 0.7634069400630915, 0.7555...  [1, 1, 7, 8, 4, 4, 7]
# 2  [0.7538994800693242, 0.48526863084922006, 0.45...  [1, 6, 6, 5, 8, 4, 5]
# 3  [0.5326492537313433, 0.396455223880597, 0.3973...  [1, 3, 5, 1, 6, 7, 1]
# 4  [0.5729459162495422, 0.5515810035404712, 0.553...  [1, 3, 4, 4, 2, 4, 3]

# %%
squiggles = empirical_train_df_subset_['squiggle'].to_numpy()
print(len(squiggles[3]))
# Out:
# 8400

# %%
# load and check the data
empirical_train_df_subset_loaded = pd.read_csv("empirical_train_dataset_v3.csv")


empirical_train_df_subset_loaded.head()
# Out:
#    Unnamed: 0  ONT_Barcode                     HW_Address  \
# 0           0            1  barcode_external01_internal01
# 1           1            1  barcode_external01_internal01
# 2           2            1  barcode_external01_internal01
# 3           3            1  barcode_external01_internal01
# 4           4            1  barcode_external01_internal01
#
#                                              Payload  \
# 0  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 1  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 2  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 3  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 4  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
#
#                                       Library_Motifs  \
# 0  ['ltm8_2x1', 'ltm8_3x3', 'ltm8_3x5', 'ltm8_4x1...
# 1  ['ltm8_3x5', 'ltm8_4x1', 'ltm8_4x1', 'ltm8_6x7...
# 2  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_4x2', 'ltm8_5x7...
# 3  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_2x1', 'ltm8_3x4...
# 4  ['ltm8_1x1', 'ltm8_3x2', 'ltm8_4x2', 'ltm8_5x1...
#
#                                 read_id  \
# 0  0804c886-cd0a-4ece-87ee-adb529974699
# 1  0f041c54-7071-49d3-8ae2-7a1bf25525ab
# 2  1361a5db-d135-4e98-bb49-7a53c8d72991
# 3  1b4284d2-bee2-4a15-abab-aad861447308
# 4  1cc7b7bb-cd90-485f-b744-cf846d566675
#
#                                             squiggle  \
# 0    [0.725  0.735  0.7525 ... 0.2275 0.2225 0.3225]
# 1  [0.525      0.48452381 0.50357143 ... 0.286904...
# 2  [0.66757991 0.50958904 0.51506849 ... 0.558904...
# 3  [0.68461538 0.54615385 0.54923077 ... 0.490769...
# 4  [0.7113164  0.66281755 0.66281755 ... 0.501154...
#
#                         Motifs
# 0        [1, 3, 5, 1, 1, 4, 5]
# 1        [5, 1, 1, 7, 7, 7, 8]
# 2     [1, 1, 2, 7, 4, 5, 6, 5]
# 3        [1, 1, 1, 4, 4, 6, 6]
# 4  [1, 2, 2, 1, 4, 8, 3, 3, 5]

# %%
len(empirical_train_df_subset_loaded['squiggle'].to_numpy()[0])
# Out:
# 47

# %%
squiggles = empirical_train_df_subset_loaded['squiggle'].to_numpy()

# %%
empirical_train_df_subset.to_pickle("empirical_train_dataset_v2.pkl")

# %%
len(empirical_train_df_subset_loaded['squiggle'].to_numpy()[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 len(empirical_train_df_subset_loaded['squiggle'].to_numpy()[3])
#
# NameError: name 'empirical_train_df_subset_loaded' is not defined

# %%
from sklearn.preprocessing import MinMaxScaler

t = [3.4, 2.3, 4.6]

MinMaxScaler().fit_transform(x.reshape(-1, 1)).reshape(-1)

# %% [markdown]
# ### Adding spacers

# %%
empirical_dataset_path = r"datasets\empirical\empirical_train_dataset_v3.pkl"

empirical_train_df_spacers = pd.read_pickle(empirical_dataset_path)

# %%
empirical_train_df_spacers.head()
# Out:
#    ONT_Barcode                     HW_Address  \
# 0            1  barcode_external01_internal01
# 1            1  barcode_external01_internal01
# 2            1  barcode_external01_internal01
# 3            1  barcode_external01_internal01
# 4            1  barcode_external01_internal01
#
#                                              Payload  \
# 0  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 1  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 2  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 3  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 4  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
#
#                                       Library_Motifs  \
# 0  ['ltm8_2x1', 'ltm8_3x3', 'ltm8_3x5', 'ltm8_4x1...
# 1  ['ltm8_3x5', 'ltm8_4x1', 'ltm8_4x1', 'ltm8_6x7...
# 2  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_4x2', 'ltm8_5x7...
# 3  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_2x1', 'ltm8_3x4...
# 4  ['ltm8_1x1', 'ltm8_3x2', 'ltm8_4x2', 'ltm8_5x1...
#
#                                 read_id  \
# 0  0804c886-cd0a-4ece-87ee-adb529974699
# 1  0f041c54-7071-49d3-8ae2-7a1bf25525ab
# 2  1361a5db-d135-4e98-bb49-7a53c8d72991
# 3  1b4284d2-bee2-4a15-abab-aad861447308
# 4  1cc7b7bb-cd90-485f-b744-cf846d566675
#
#                                             squiggle  \
# 0  [0.7250000000000001, 0.7350000000000001, 0.752...
# 1  [0.525, 0.4845238095238096, 0.5035714285714287...
# 2  [0.6675799086757991, 0.5095890410958903, 0.515...
# 3  [0.6846153846153846, 0.5461538461538461, 0.549...
# 4  [0.7113163972286374, 0.6628175519630484, 0.662...
#
#                         Motifs
# 0        [1, 3, 5, 1, 1, 4, 5]
# 1        [5, 1, 1, 7, 7, 7, 8]
# 2     [1, 1, 2, 7, 4, 5, 6, 5]
# 3        [1, 1, 1, 4, 4, 6, 6]
# 4  [1, 2, 2, 1, 4, 8, 3, 3, 5]

# %%
def extract_cycle_motif(library_motif):
    
        if library_motif[6] == 'x':
            cycle_number = int(library_motif[5])
            motif_number = int(library_motif[7])
        else:
            cycle_number = int(library_motif[5:7])
            motif_number = int(library_motif[8])
        

        return cycle_number, motif_number

def create_spacer_sequence(library_motifs):

    cycle_number = 0
    motif_number = 0

    spacer_sequence = []

    for i in library_motifs:

        cycle_number, motif_number = extract_cycle_motif(i)

        # So we add a prior spacer and then a post spacer, cause that's what a motif is
        spacer_sequence.append(cycle_number + 8)
        spacer_sequence.append(motif_number)
        spacer_sequence.append(cycle_number + 8)

        if i == 1:
            motif_number+=1
        else:
            cycle_number+=1

    return spacer_sequence

spacer_sequences = []
for i in empirical_train_df_spacers['Library_Motifs']:
    spacer_sequences.append(create_spacer_sequence(eval(i)))

# %%
spacer_sequences
# Out:
# [[10, 1, 10, 11, 3, 11, 11, 5, 11, 12, 1, 12, 13, 1, 13, 14, 4, 14, 15, 5, 15],
#  [11, 5, 11, 12, 1, 12, 12, 1, 12, 14, 7, 14, 14, 7, 14, 15, 7, 15, 16, 8, 16],
#  [9,
#   1,
#   9,
#   10,
#   1,
#   10,
#   12,
#   2,
#   12,
#   13,
#   7,
#   13,
#   14,
#   4,
#   14,
#   15,
#   5,
#   15,
#   16,
#   6,
#   16,
#   17,
#   5,
#   17],
#  [9, 1, 9, 10, 1, 10, 10, 1, 10, 11, 4, 11, 13, 4, 13, 14, 6, 14, 16, 6, 16],
#  [9,
#   1,
#   9,
#   11,
#   2,
#   11,
#   12,
#   2,
#   12,
#   13,
#   1,
#   13,
#   14,
#   4,
#   14,
#   15,
#   8,
#   15,
#   16,
#   3,
#   16,
#   17,
#   3,
#   17,
#   18,
#   5,
#   18],
#  [10, 1, 10, 13, 5, 13, 14, 6, 14, 15, 2, 15, 16, 3, 16, 17, 3, 17, 18, 7, 18],
#  [10,
#   1,
#   10,
#   11,
#   4,
#   11,
#   14,
#   8,
#   14,
#   15,
#   2,
#   15,
#   15,
#   2,
#   15,
#   16,
#   5,
#   16,
#   17,
#   1,
#   17,
#   17,
#   5,
#   17],
#  [11, 3, 11, 12, 2, 12, 13, 2, 13, 13, 8, 13, 14, 2, 14, 14, 4, 14, 15, 3, 15],
#  [9, 1, 9, 10, 1, 10, 12, 8, 12, 13, 6, 13, 14, 4, 14, 15, 2, 15, 17, 5, 17],
#  [10,
#   1,
#   10,
#   12,
#   8,
#   12,
#   13,
#   1,
#   13,
#   14,
#   7,
#   14,
#   15,
#   1,
#   15,
#   15,
#   7,
#   15,
#   16,
#   2,
#   16,
#   16,
#   4,
#   16],
#  [11, 2, 11, 12, 7, 12, 14, 7, 14, 15, 5, 15, 16, 6, 16, 17, 5, 17, 18, 6, 18],
#  [10, 1, 10, 11, 1, 11, 11, 8, 11, 13, 7, 13, 14, 8, 14, 15, 7, 15, 17, 4, 17],
#  [9,
#   1,
#   9,
#   10,
#   1,
#   10,
#   10,
#   1,
#   10,
#   11,
#   3,
#   11,
#   14,
#   8,
#   14,
#   14,
#   8,
#   14,
#   15,
#   7,
#   15,
#   16,
#   5,
#   16,
#   18,
#   1,
#   18],
#  [9, 1, 9, 10, 1, 10, 11, 2, 11, 12, 1, 12, 13, 6, 13, 16, 3, 16, 17, 1, 17],
#  [9,
#   1,
#   9,
#   10,
#   1,
#   10,
#   11,
#   5,
#   11,
#   12,
#   1,
#   12,
#   13,
#   6,
#   13,
#   14,
#   7,
#   14,
#   17,
#   1,
#   17,
#   18,
#   6,
#   18],
#  [9, 1, 9, 10, 1, 10, 11, 4, 11, 12, 1, 12, 13, 1, 13, 17, 5, 17, 18, 5, 18],
#  [9, 1, 9, 10, 1, 10, 12, 1, 12, 13, 1, 13, 15, 5, 15, 16, 3, 16, 17, 5, 17],
#  [13, 4, 13, 13, 6, 13, 14, 2, 14, 16, 1, 16, 16, 7, 16, 17, 8, 17, 18, 4, 18],
#  [9, 1, 9, 10, 1, 10, 12, 1, 12, 13, 6, 13, 14, 4, 14, 17, 7, 17, 18, 5, 18],
#  [9, 1, 9, 10, 1, 10, 12, 8, 12, 13, 5, 13, 13, 6, 13, 16, 8, 16, 17, 3, 17],
#  [11, 5, 11, 12, 1, 12, 13, 6, 13, 14, 4, 14, 15, 7, 15, 16, 6, 16, 18, 6, 18],
#  [10, 1, 10, 11, 1, 11, 12, 6, 12, 15, 7, 15, 16, 6, 16, 17, 7, 17, 18, 6, 18],
#  [10, 1, 10, 13, 1, 13, 14, 7, 14, 14, 8, 14, 15, 8, 15, 16, 3, 16, 16, 6, 16],
#  [10, 1, 10, 11, 1, 11, 12, 7, 12, 13, 7, 13, 14, 1, 14, 15, 5, 15, 18, 4, 18],
#  [9, 1, 9, 10, 1, 10, 12, 1, 12, 13, 1, 13, 13, 5, 13, 14, 4, 14, 15, 7, 15],
#  [10,
#   1,
#   10,
#   12,
#   7,
#   12,
#   13,
#   5,
#   13,
#   14,
#   4,
#   14,
#   15,
#   2,
#   15,
#   16,
#   8,
#   16,
#   17,
#   5,
#   17,
#   18,
#   7,
#   18],
#  [9, 1, 9, 10, 1, 10, 11, 4, 11, 12, 8, 12, 13, 6, 13, 14, 8, 14, 15, 5, 15],
#  [9, 1, 9, 11, 3, 11, 12, 8, 12, 13, 1, 13, 15, 7, 15, 16, 8, 16, 17, 1, 17],
#  [10,
#   1,
#   10,
#   11,
#   4,
#   11,
#   12,
#   8,
#   12,
#   12,
#   8,
#   12,
#   14,
#   6,
#   14,
#   14,
#   8,
#   14,
#   17,
#   1,
#   17,
#   18,
#   1,
#   18],
#  [10, 1, 10, 11, 1, 11, 12, 1, 12, 15, 3, 15, 16, 7, 16, 17, 2, 17, 18, 1, 18],
#  [9, 2, 9, 10, 1, 10, 11, 4, 11, 12, 4, 12, 13, 6, 13, 16, 1, 16, 17, 1, 17],
#  [9, 2, 9, 10, 1, 10, 11, 3, 11, 13, 6, 13, 14, 6, 14, 17, 6, 17, 18, 7, 18],
#  [9,
#   2,
#   9,
#   10,
#   1,
#   10,
#   11,
#   4,
#   11,
#   12,
#   2,
#   12,
#   13,
#   6,
#   13,
#   14,
#   8,
#   14,
#   16,
#   7,
#   16,
#   17,
#   6,
#   17,
#   18,
#   7,
#   18],
#  [9,
#   2,
#   9,
#   10,
#   1,
#   10,
#   11,
#   4,
#   11,
#   12,
#   8,
#   12,
#   13,
#   4,
#   13,
#   15,
#   5,
#   15,
#   16,
#   8,
#   16,
#   17,
#   8,
#   17,
#   18,
#   1,
#   18],
#  [9,
#   2,
#   9,
#   12,
#   2,
#   12,
#   12,
#   8,
#   12,
#   12,
#   8,
#   12,
#   13,
#   4,
#   13,
#   13,
#   7,
#   13,
#   15,
#   1,
#   15,
#   17,
#   1,
#   17,
#   18,
#   6,
#   18],
#  [9,
#   2,
#   9,
#   11,
#   8,
#   11,
#   12,
#   8,
#   12,
#   14,
#   6,
#   14,
#   16,
#   1,
#   16,
#   17,
#   6,
#   17,
#   18,
#   1,
#   18,
#   18,
#   6,
#   18],
#  [9,
#   2,
#   9,
#   10,
#   1,
#   10,
#   11,
#   3,
#   11,
#   12,
#   2,
#   12,
#   14,
#   6,
#   14,
#   14,
#   7,
#   14,
#   15,
#   1,
#   15,
#   16,
#   1,
#   16,
#   17,
#   5,
#   17,
#   18,
#   7,
#   18],
#  [9, 2, 9, 10, 1, 10, 12, 8, 12, 13, 4, 13, 14, 6, 14, 17, 1, 17, 18, 5, 18],
#  [9,
#   2,
#   9,
#   10,
#   1,
#   10,
#   11,
#   4,
#   11,
#   12,
#   8,
#   12,
#   12,
#   8,
#   12,
#   13,
#   6,
#   13,
#   14,
#   7,
#   14,
#   15,
#   8,
#   15,
#   18,
#   6,
#   18],
#  [9,
#   2,
#   9,
#   10,
#   1,
#   10,
#   11,
#   4,
#   11,
#   12,
#   2,
#   12,
#   14,
#   1,
#   14,
#   16,
#   8,
#   16,
#   17,
#   6,
#   17,
#   18,
#   7,
#   18],
#  [10,
#   1,
#   10,
#   12,
#   3,
#   12,
#   13,
#   7,
#   13,
#   14,
#   6,
#   14,
#   15,
#   8,
#   15,
#   16,
#   1,
#   16,
#   17,
#   1,
#   17,
#   18,
#   7,
#   18],
#  [11, 4, 11, 12, 2, 12, 13, 4, 13, 14, 1, 14, 14, 6, 14, 15, 1, 15, 18, 6, 18],
#  [9,
#   5,
#   9,
#   10,
#   3,
#   10,
#   11,
#   1,
#   11,
#   11,
#   7,
#   11,
#   12,
#   8,
#   12,
#   13,
#   8,
#   13,
#   14,
#   5,
#   14,
#   16,
#   7,
#   16,
#   16,
#   7,
#   16,
#   17,
#   3,
#   17],
#  [9,
#   2,
#   9,
#   10,
#   1,
#   10,
#   11,
#   3,
#   11,
#   12,
#   8,
#   12,
#   13,
#   6,
#   13,
#   14,
#   7,
#   14,
#   15,
#   1,
#   15,
#   16,
#   8,
#   16],
#  [9,
#   2,
#   9,
#   10,
#   1,
#   10,
#   11,
#   3,
#   11,
#   12,
#   2,
#   12,
#   13,
#   2,
#   13,
#   15,
#   8,
#   15,
#   16,
#   8,
#   16,
#   17,
#   1,
#   17],
#  [9, 3, 9, 10, 1, 10, 11, 3, 11, 12, 2, 12, 12, 6, 12, 13, 8, 13, 14, 2, 14],
#  [9,
#   6,
#   9,
#   10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   11,
#   4,
#   11,
#   12,
#   6,
#   12,
#   13,
#   5,
#   13,
#   13,
#   6,
#   13,
#   14,
#   1,
#   14,
#   14,
#   1,
#   14,
#   15,
#   5,
#   15,
#   16,
#   7,
#   16,
#   17,
#   1,
#   17,
#   18,
#   6,
#   18],
#  [9, 3, 9, 10, 1, 10, 11, 1, 11, 12, 2, 12, 13, 5, 13, 15, 2, 15, 16, 7, 16],
#  [9, 3, 9, 11, 5, 11, 14, 2, 14, 15, 5, 15, 16, 8, 16, 17, 5, 17, 18, 8, 18],
#  [9,
#   3,
#   9,
#   10,
#   1,
#   10,
#   11,
#   3,
#   11,
#   13,
#   8,
#   13,
#   14,
#   2,
#   14,
#   16,
#   4,
#   16,
#   17,
#   5,
#   17,
#   18,
#   8,
#   18],
#  [9,
#   3,
#   9,
#   10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   12,
#   2,
#   12,
#   13,
#   5,
#   13,
#   15,
#   5,
#   15,
#   16,
#   2,
#   16,
#   17,
#   5,
#   17],
#  [10,
#   1,
#   10,
#   11,
#   3,
#   11,
#   12,
#   5,
#   12,
#   13,
#   5,
#   13,
#   13,
#   8,
#   13,
#   14,
#   1,
#   14,
#   14,
#   4,
#   14,
#   15,
#   6,
#   15],
#  [9,
#   3,
#   9,
#   10,
#   1,
#   10,
#   11,
#   5,
#   11,
#   12,
#   5,
#   12,
#   13,
#   8,
#   13,
#   14,
#   2,
#   14,
#   15,
#   5,
#   15,
#   16,
#   2,
#   16],
#  [9,
#   3,
#   9,
#   10,
#   1,
#   10,
#   11,
#   8,
#   11,
#   12,
#   2,
#   12,
#   13,
#   6,
#   13,
#   14,
#   6,
#   14,
#   15,
#   5,
#   15,
#   17,
#   4,
#   17],
#  [9, 3, 9, 10, 1, 10, 11, 3, 11, 13, 6, 13, 14, 2, 14, 16, 7, 16, 18, 7, 18],
#  [11, 3, 11, 12, 4, 12, 13, 1, 13, 14, 4, 14, 16, 4, 16, 17, 4, 17, 18, 5, 18],
#  [10,
#   1,
#   10,
#   11,
#   8,
#   11,
#   12,
#   4,
#   12,
#   13,
#   5,
#   13,
#   14,
#   1,
#   14,
#   14,
#   6,
#   14,
#   15,
#   6,
#   15,
#   15,
#   8,
#   15,
#   16,
#   2,
#   16],
#  [9, 3, 9, 10, 1, 10, 11, 3, 11, 12, 6, 12, 13, 1, 13, 16, 8, 16, 18, 5, 18],
#  [10, 1, 10, 11, 1, 11, 12, 4, 12, 13, 1, 13, 14, 4, 14, 15, 2, 15, 17, 4, 17],
#  [9,
#   3,
#   9,
#   12,
#   6,
#   12,
#   13,
#   1,
#   13,
#   14,
#   1,
#   14,
#   14,
#   2,
#   14,
#   15,
#   8,
#   15,
#   16,
#   2,
#   16,
#   16,
#   4,
#   16],
#  [9, 3, 9, 11, 5, 11, 12, 2, 12, 15, 6, 15, 16, 7, 16, 17, 1, 17, 18, 7, 18],
#  [10, 1, 10, 12, 4, 12, 13, 5, 13, 14, 1, 14, 15, 5, 15, 16, 8, 16, 18, 8, 18],
#  [9, 3, 9, 10, 1, 10, 11, 3, 11, 13, 6, 13, 16, 7, 16, 17, 5, 17, 18, 2, 18],
#  [9,
#   3,
#   9,
#   10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   12,
#   6,
#   12,
#   13,
#   6,
#   13,
#   14,
#   2,
#   14,
#   15,
#   6,
#   15,
#   16,
#   7,
#   16],
#  [9,
#   3,
#   9,
#   10,
#   1,
#   10,
#   12,
#   5,
#   12,
#   12,
#   6,
#   12,
#   13,
#   1,
#   13,
#   13,
#   6,
#   13,
#   14,
#   1,
#   14,
#   15,
#   8,
#   15,
#   16,
#   8,
#   16],
#  [10, 1, 10, 11, 3, 11, 12, 5, 12, 13, 6, 13, 14, 1, 14, 15, 5, 15, 18, 2, 18],
#  [9,
#   3,
#   9,
#   10,
#   1,
#   10,
#   11,
#   3,
#   11,
#   12,
#   5,
#   12,
#   13,
#   1,
#   13,
#   13,
#   6,
#   13,
#   14,
#   2,
#   14,
#   14,
#   6,
#   14,
#   15,
#   5,
#   15,
#   15,
#   6,
#   15,
#   16,
#   4,
#   16,
#   17,
#   4,
#   17,
#   18,
#   7,
#   18],
#  [9, 3, 9, 10, 1, 10, 12, 6, 12, 13, 8, 13, 14, 6, 14, 15, 5, 15, 16, 2, 16],
#  [9,
#   3,
#   9,
#   10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   12,
#   2,
#   12,
#   14,
#   6,
#   14,
#   15,
#   5,
#   15,
#   16,
#   2,
#   16,
#   17,
#   7,
#   17],
#  [9, 4, 9, 11, 5, 11, 13, 8, 13, 14, 4, 14, 15, 6, 15, 16, 1, 16, 18, 4, 18],
#  [11, 4, 11, 12, 1, 12, 13, 2, 13, 14, 1, 14, 15, 6, 15, 17, 2, 17, 18, 8, 18],
#  [11, 8, 11, 12, 3, 12, 13, 4, 13, 14, 7, 14, 15, 1, 15, 17, 4, 17, 18, 2, 18],
#  [9,
#   6,
#   9,
#   11,
#   2,
#   11,
#   12,
#   1,
#   12,
#   12,
#   3,
#   12,
#   13,
#   8,
#   13,
#   14,
#   6,
#   14,
#   14,
#   6,
#   14,
#   15,
#   7,
#   15,
#   15,
#   7,
#   15,
#   16,
#   1,
#   16],
#  [10, 1, 10, 13, 1, 13, 13, 4, 13, 15, 1, 15, 16, 4, 16, 17, 4, 17, 18, 6, 18],
#  [9,
#   4,
#   9,
#   10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   13,
#   8,
#   13,
#   14,
#   8,
#   14,
#   15,
#   6,
#   15,
#   16,
#   1,
#   16,
#   18,
#   7,
#   18],
#  [10, 1, 10, 11, 1, 11, 12, 3, 12, 13, 7, 13, 14, 1, 14, 15, 5, 15, 17, 4, 17],
#  [10, 1, 10, 11, 4, 11, 13, 1, 13, 14, 4, 14, 16, 4, 16, 17, 3, 17, 18, 7, 18],
#  [10, 1, 10, 11, 4, 11, 11, 5, 11, 12, 4, 12, 13, 4, 13, 15, 7, 15, 17, 4, 17],
#  [13, 1, 13, 13, 4, 13, 14, 1, 14, 14, 8, 14, 15, 7, 15, 16, 4, 16, 17, 4, 17],
#  [10, 1, 10, 11, 1, 11, 12, 8, 12, 13, 1, 13, 13, 4, 13, 16, 3, 16, 16, 7, 16],
#  [9,
#   4,
#   9,
#   10,
#   1,
#   10,
#   11,
#   8,
#   11,
#   13,
#   1,
#   13,
#   14,
#   7,
#   14,
#   15,
#   7,
#   15,
#   16,
#   4,
#   16,
#   18,
#   4,
#   18],
#  [9,
#   4,
#   9,
#   10,
#   1,
#   10,
#   11,
#   5,
#   11,
#   12,
#   4,
#   12,
#   13,
#   4,
#   13,
#   14,
#   1,
#   14,
#   15,
#   7,
#   15,
#   16,
#   1,
#   16],
#  [9, 4, 9, 10, 1, 10, 13, 1, 13, 14, 1, 14, 15, 6, 15, 16, 1, 16, 18, 2, 18],
#  [10, 1, 10, 11, 5, 11, 13, 8, 13, 15, 5, 15, 16, 4, 16, 17, 3, 17, 18, 4, 18],
#  [11, 1, 11, 13, 8, 13, 14, 4, 14, 15, 1, 15, 16, 6, 16, 17, 1, 17, 18, 8, 18],
#  [9, 4, 9, 10, 1, 10, 11, 4, 11, 13, 4, 13, 14, 8, 14, 15, 5, 15, 17, 1, 17],
#  [9,
#   4,
#   9,
#   11,
#   4,
#   11,
#   12,
#   8,
#   12,
#   13,
#   7,
#   13,
#   13,
#   8,
#   13,
#   14,
#   1,
#   14,
#   14,
#   1,
#   14,
#   14,
#   8,
#   14,
#   17,
#   1,
#   17],
#  [9, 4, 9, 10, 1, 10, 12, 7, 12, 13, 1, 13, 14, 1, 14, 15, 5, 15, 16, 7, 16],
#  [9,
#   4,
#   9,
#   10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   12,
#   8,
#   12,
#   15,
#   7,
#   15,
#   16,
#   1,
#   16,
#   17,
#   4,
#   17,
#   18,
#   2,
#   18],
#  [9, 4, 9, 10, 1, 10, 12, 8, 12, 14, 1, 14, 15, 5, 15, 17, 3, 17, 18, 2, 18],
#  [9,
#   4,
#   9,
#   10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   11,
#   8,
#   11,
#   12,
#   3,
#   12,
#   12,
#   8,
#   12,
#   13,
#   1,
#   13,
#   13,
#   7,
#   13,
#   14,
#   7,
#   14,
#   14,
#   8,
#   14,
#   15,
#   6,
#   15],
#  [11, 4, 11, 13, 7, 13, 14, 4, 14, 15, 5, 15, 16, 1, 16, 17, 3, 17, 18, 6, 18],
#  [9,
#   4,
#   9,
#   10,
#   1,
#   10,
#   11,
#   4,
#   11,
#   13,
#   7,
#   13,
#   13,
#   7,
#   13,
#   14,
#   8,
#   14,
#   15,
#   1,
#   15,
#   17,
#   3,
#   17],
#  [10, 1, 10, 11, 4, 11, 12, 4, 12, 15, 5, 15, 16, 2, 16, 17, 2, 17, 18, 6, 18],
#  [9,
#   4,
#   9,
#   10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   12,
#   8,
#   12,
#   13,
#   8,
#   13,
#   14,
#   1,
#   14,
#   16,
#   1,
#   16,
#   17,
#   3,
#   17],
#  [9, 4, 9, 10, 1, 10, 11, 1, 11, 12, 8, 12, 15, 1, 15, 17, 1, 17, 18, 7, 18],
#  [9,
#   4,
#   9,
#   10,
#   1,
#   10,
#   11,
#   8,
#   11,
#   12,
#   8,
#   12,
#   13,
#   8,
#   13,
#   14,
#   7,
#   14,
#   15,
#   5,
#   15,
#   16,
#   4,
#   16],
#  [12, 4, 12, 13, 8, 13, 14, 1, 14, 15, 1, 15, 16, 7, 16, 17, 3, 17, 18, 4, 18],
#  [9,
#   4,
#   9,
#   10,
#   1,
#   10,
#   11,
#   5,
#   11,
#   13,
#   8,
#   13,
#   14,
#   7,
#   14,
#   15,
#   7,
#   15,
#   16,
#   4,
#   16,
#   17,
#   1,
#   17,
#   18,
#   7,
#   18],
#  [9,
#   4,
#   9,
#   10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   12,
#   3,
#   12,
#   13,
#   7,
#   13,
#   14,
#   8,
#   14,
#   15,
#   7,
#   15,
#   16,
#   1,
#   16,
#   17,
#   3,
#   17],
#  [10, 1, 10, 11, 1, 11, 12, 8, 12, 14, 1, 14, 15, 1, 15, 16, 1, 16, 17, 4, 17],
#  [9, 5, 9, 11, 2, 11, 12, 7, 12, 14, 4, 14, 15, 4, 15, 17, 8, 17, 18, 4, 18],
#  [9, 5, 9, 10, 1, 10, 11, 6, 11, 12, 4, 12, 16, 1, 16, 17, 7, 17, 18, 5, 18],
#  [9,
#   5,
#   9,
#   10,
#   1,
#   10,
#   11,
#   4,
#   11,
#   12,
#   4,
#   12,
#   13,
#   5,
#   13,
#   14,
#   1,
#   14,
#   15,
#   6,
#   15,
#   16,
#   6,
#   16,
#   17,
#   4,
#   17],
#  [9,
#   5,
#   9,
#   11,
#   2,
#   11,
#   11,
#   5,
#   11,
#   13,
#   6,
#   13,
#   13,
#   8,
#   13,
#   14,
#   4,
#   14,
#   15,
#   5,
#   15,
#   17,
#   7,
#   17],
#  [10,
#   1,
#   10,
#   11,
#   2,
#   11,
#   12,
#   7,
#   12,
#   13,
#   5,
#   13,
#   15,
#   8,
#   15,
#   16,
#   6,
#   16,
#   17,
#   4,
#   17,
#   18,
#   5,
#   18],
#  [9, 5, 9, 10, 1, 10, 11, 2, 11, 12, 4, 12, 15, 4, 15, 16, 1, 16, 18, 7, 18],
#  [9, 5, 9, 10, 1, 10, 11, 6, 11, 12, 3, 12, 13, 8, 13, 14, 8, 14, 18, 8, 18],
#  [9,
#   5,
#   9,
#   10,
#   1,
#   10,
#   11,
#   5,
#   11,
#   13,
#   6,
#   13,
#   14,
#   8,
#   14,
#   15,
#   6,
#   15,
#   16,
#   1,
#   16,
#   17,
#   4,
#   17,
#   18,
#   7,
#   18],
#  [9, 5, 9, 11, 2, 11, 13, 8, 13, 14, 8, 14, 15, 6, 15, 17, 4, 17, 18, 4, 18],
#  [9, 5, 9, 10, 1, 10, 10, 1, 10, 11, 5, 11, 11, 6, 11, 12, 6, 12, 17, 7, 17],
#  [10,
#   1,
#   10,
#   12,
#   6,
#   12,
#   12,
#   7,
#   12,
#   13,
#   5,
#   13,
#   13,
#   6,
#   13,
#   14,
#   4,
#   14,
#   15,
#   4,
#   15,
#   16,
#   4,
#   16,
#   16,
#   4,
#   16,
#   17,
#   2,
#   17,
#   17,
#   4,
#   17,
#   18,
#   8,
#   18],
#  [9, 5, 9, 10, 1, 10, 11, 5, 11, 13, 6, 13, 14, 5, 14, 15, 6, 15, 17, 7, 17],
#  [9, 5, 9, 11, 5, 11, 13, 4, 13, 14, 1, 14, 14, 4, 14, 15, 6, 15, 16, 4, 16],
#  [11, 1, 11, 12, 2, 12, 13, 8, 13, 14, 4, 14, 15, 5, 15, 17, 3, 17, 18, 2, 18],
#  [9, 5, 9, 10, 1, 10, 11, 4, 11, 11, 5, 11, 13, 4, 13, 13, 8, 13, 14, 1, 14],
#  [11, 4, 11, 12, 4, 12, 13, 4, 13, 14, 5, 14, 15, 5, 15, 16, 6, 16, 18, 5, 18],
#  [10, 1, 10, 10, 1, 10, 11, 5, 11, 13, 5, 13, 14, 1, 14, 16, 2, 16, 17, 7, 17],
#  [9, 5, 9, 11, 6, 11, 12, 3, 12, 13, 8, 13, 14, 1, 14, 15, 4, 15, 17, 4, 17],
#  [10,
#   1,
#   10,
#   11,
#   6,
#   11,
#   12,
#   3,
#   12,
#   13,
#   5,
#   13,
#   14,
#   4,
#   14,
#   16,
#   1,
#   16,
#   17,
#   8,
#   17,
#   18,
#   4,
#   18],
#  [9, 5, 9, 10, 1, 10, 11, 4, 11, 12, 7, 12, 13, 6, 13, 15, 4, 15, 17, 2, 17],
#  [10,
#   1,
#   10,
#   10,
#   1,
#   10,
#   11,
#   4,
#   11,
#   11,
#   5,
#   11,
#   13,
#   8,
#   13,
#   14,
#   1,
#   14,
#   15,
#   8,
#   15,
#   16,
#   4,
#   16,
#   18,
#   4,
#   18],
#  [9,
#   5,
#   9,
#   10,
#   1,
#   10,
#   11,
#   5,
#   11,
#   12,
#   4,
#   12,
#   12,
#   7,
#   12,
#   13,
#   5,
#   13,
#   14,
#   5,
#   14,
#   18,
#   7,
#   18],
#  [11, 5, 11, 12, 6, 12, 13, 6, 13, 14, 4, 14, 15, 4, 15, 16, 2, 16, 17, 4, 17],
#  [10, 1, 10, 11, 6, 11, 13, 8, 13, 14, 4, 14, 15, 5, 15, 16, 1, 16, 17, 8, 17],
#  [9, 5, 9, 10, 1, 10, 11, 6, 11, 13, 8, 13, 14, 8, 14, 15, 8, 15, 18, 7, 18],
#  [10, 1, 10, 11, 6, 11, 12, 7, 12, 13, 4, 13, 14, 1, 14, 15, 4, 15, 18, 7, 18],
#  [12,
#   3,
#   12,
#   12,
#   6,
#   12,
#   13,
#   4,
#   13,
#   13,
#   5,
#   13,
#   13,
#   5,
#   13,
#   15,
#   6,
#   15,
#   16,
#   4,
#   16,
#   17,
#   7,
#   17],
#  [9, 5, 9, 10, 1, 10, 12, 6, 12, 13, 5, 13, 15, 4, 15, 16, 1, 16, 18, 5, 18],
#  [9, 5, 9, 10, 1, 10, 11, 5, 11, 12, 6, 12, 13, 6, 13, 15, 4, 15, 17, 8, 17],
#  [9,
#   5,
#   9,
#   10,
#   1,
#   10,
#   12,
#   7,
#   12,
#   13,
#   4,
#   13,
#   13,
#   7,
#   13,
#   14,
#   3,
#   14,
#   14,
#   4,
#   14,
#   14,
#   5,
#   14,
#   15,
#   5,
#   15],
#  [9, 5, 9, 10, 1, 10, 11, 4, 11, 11, 6, 11, 12, 7, 12, 13, 8, 13, 17, 4, 17],
#  [10,
#   1,
#   10,
#   12,
#   7,
#   12,
#   13,
#   5,
#   13,
#   13,
#   6,
#   13,
#   14,
#   1,
#   14,
#   14,
#   1,
#   14,
#   15,
#   4,
#   15,
#   15,
#   4,
#   15,
#   16,
#   4,
#   16],
#  [11, 1, 11, 12, 7, 12, 13, 3, 13, 13, 5, 13, 15, 8, 15, 16, 1, 16, 17, 2, 17],
#  [9, 5, 9, 10, 1, 10, 11, 6, 11, 12, 3, 12, 13, 6, 13, 16, 1, 16, 18, 7, 18],
#  [9,
#   5,
#   9,
#   10,
#   1,
#   10,
#   11,
#   2,
#   11,
#   12,
#   3,
#   12,
#   13,
#   8,
#   13,
#   14,
#   4,
#   14,
#   16,
#   6,
#   16,
#   18,
#   5,
#   18],
#  [9, 5, 9, 10, 1, 10, 11, 2, 11, 12, 4, 12, 13, 6, 13, 14, 1, 14, 15, 5, 15],
#  [10, 1, 10, 11, 2, 11, 12, 4, 12, 13, 3, 13, 14, 7, 14, 16, 2, 16, 17, 5, 17],
#  [10, 1, 10, 11, 5, 11, 12, 3, 12, 13, 3, 13, 15, 3, 15, 17, 5, 17, 18, 1, 18],
#  [9, 6, 9, 10, 1, 10, 11, 4, 11, 12, 1, 12, 13, 3, 13, 14, 2, 14, 15, 3, 15],
#  [9,
#   6,
#   9,
#   11,
#   5,
#   11,
#   12,
#   6,
#   12,
#   13,
#   7,
#   13,
#   14,
#   6,
#   14,
#   15,
#   1,
#   15,
#   15,
#   3,
#   15,
#   18,
#   4,
#   18],
#  [9, 6, 9, 10, 1, 10, 11, 4, 11, 12, 3, 12, 14, 6, 14, 16, 5, 16, 17, 1, 17],
#  [10, 1, 10, 12, 1, 12, 12, 6, 12, 13, 3, 13, 14, 2, 14, 14, 6, 14, 16, 2, 16],
#  [9, 6, 9, 10, 1, 10, 11, 2, 11, 12, 3, 12, 12, 6, 12, 13, 6, 13, 15, 1, 15],
#  [10, 1, 10, 11, 2, 11, 12, 1, 12, 14, 6, 14, 15, 5, 15, 16, 2, 16, 17, 5, 17],
#  [9, 6, 9, 10, 1, 10, 11, 4, 11, 12, 3, 12, 14, 6, 14, 15, 5, 15, 17, 8, 17],
#  [9, 6, 9, 10, 1, 10, 11, 4, 11, 13, 6, 13, 15, 3, 15, 17, 2, 17, 18, 7, 18],
#  [10, 1, 10, 11, 5, 11, 12, 1, 12, 15, 3, 15, 16, 5, 16, 17, 8, 17, 18, 7, 18],
#  [9,
#   6,
#   9,
#   10,
#   1,
#   10,
#   11,
#   4,
#   11,
#   11,
#   5,
#   11,
#   12,
#   3,
#   12,
#   13,
#   6,
#   13,
#   14,
#   4,
#   14,
#   14,
#   6,
#   14,
#   15,
#   3,
#   15,
#   17,
#   2,
#   17],
#  [10,
#   1,
#   10,
#   11,
#   7,
#   11,
#   12,
#   3,
#   12,
#   13,
#   1,
#   13,
#   14,
#   7,
#   14,
#   15,
#   3,
#   15,
#   16,
#   3,
#   16,
#   17,
#   1,
#   17],
#  [9, 6, 9, 10, 1, 10, 11, 5, 11, 12, 6, 12, 13, 3, 13, 14, 2, 14, 15, 5, 15],
#  [9, 6, 9, 10, 1, 10, 12, 6, 12, 13, 1, 13, 14, 6, 14, 15, 5, 15, 18, 4, 18],
#  [9,
#   2,
#   9,
#   9,
#   6,
#   9,
#   11,
#   8,
#   11,
#   12,
#   6,
#   12,
#   14,
#   6,
#   14,
#   15,
#   1,
#   15,
#   16,
#   7,
#   16,
#   17,
#   6,
#   17,
#   18,
#   6,
#   18],
#  [9,
#   6,
#   9,
#   10,
#   1,
#   10,
#   11,
#   2,
#   11,
#   12,
#   1,
#   12,
#   13,
#   7,
#   13,
#   14,
#   7,
#   14,
#   17,
#   8,
#   17,
#   18,
#   1,
#   18],
#  [10, 1, 10, 11, 4, 11, 13, 3, 13, 15, 1, 15, 16, 3, 16, 17, 1, 17, 18, 1, 18],
#  [9,
#   6,
#   9,
#   10,
#   1,
#   10,
#   11,
#   2,
#   11,
#   12,
#   3,
#   12,
#   13,
#   7,
#   13,
#   14,
#   4,
#   14,
#   15,
#   1,
#   15,
#   16,
#   3,
#   16,
#   17,
#   5,
#   17,
#   18,
#   6,
#   18],
#  [11, 7, 11, 12, 1, 12, 13, 1, 13, 13, 3, 13, 14, 2, 14, 15, 1, 15, 16, 4, 16],
#  [9,
#   6,
#   9,
#   10,
#   1,
#   10,
#   11,
#   4,
#   11,
#   12,
#   3,
#   12,
#   13,
#   3,
#   13,
#   15,
#   1,
#   15,
#   17,
#   5,
#   17,
#   18,
#   7,
#   18],
#  [9, 6, 9, 10, 1, 10, 11, 5, 11, 12, 6, 12, 15, 1, 15, 17, 1, 17, 18, 4, 18],
#  [9, 6, 9, 10, 1, 10, 11, 2, 11, 13, 7, 13, 14, 6, 14, 15, 4, 15, 17, 8, 17],
#  [9, 6, 9, 10, 1, 10, 11, 7, 11, 12, 3, 12, 13, 3, 13, 17, 1, 17, 18, 7, 18],
#  [9, 6, 9, 11, 5, 11, 14, 7, 14, 15, 4, 15, 16, 4, 16, 17, 8, 17, 18, 6, 18],
#  [9, 6, 9, 10, 1, 10, 11, 4, 11, 12, 6, 12, 13, 7, 13, 14, 2, 14, 15, 1, 15],
#  [12,
#   1,
#   12,
#   13,
#   6,
#   13,
#   15,
#   1,
#   15,
#   15,
#   4,
#   15,
#   16,
#   4,
#   16,
#   16,
#   5,
#   16,
#   17,
#   2,
#   17,
#   17,
#   5,
#   17],
#  [10,
#   1,
#   10,
#   11,
#   7,
#   11,
#   12,
#   4,
#   12,
#   13,
#   1,
#   13,
#   13,
#   1,
#   13,
#   14,
#   2,
#   14,
#   14,
#   6,
#   14,
#   15,
#   3,
#   15,
#   15,
#   4,
#   15],
#  [9,
#   6,
#   9,
#   11,
#   4,
#   11,
#   12,
#   1,
#   12,
#   13,
#   1,
#   13,
#   15,
#   1,
#   15,
#   16,
#   5,
#   16,
#   17,
#   5,
#   17,
#   18,
#   7,
#   18],
#  [9, 6, 9, 10, 1, 10, 12, 1, 12, 15, 1, 15, 16, 3, 16, 17, 1, 17, 18, 4, 18],
#  [9, 6, 9, 10, 1, 10, 12, 6, 12, 14, 4, 14, 15, 3, 15, 17, 5, 17, 18, 4, 18],
#  [9,
#   6,
#   9,
#   11,
#   4,
#   11,
#   12,
#   3,
#   12,
#   13,
#   1,
#   13,
#   14,
#   2,
#   14,
#   15,
#   1,
#   15,
#   16,
#   4,
#   16,
#   17,
#   8,
#   17,
#   18,
#   4,
#   18],
#  [10,
#   1,
#   10,
#   11,
#   5,
#   11,
#   13,
#   8,
#   13,
#   14,
#   8,
#   14,
#   15,
#   1,
#   15,
#   16,
#   3,
#   16,
#   17,
#   5,
#   17,
#   18,
#   4,
#   18],
#  [9, 7, 9, 10, 1, 10, 12, 7, 12, 13, 2, 13, 14, 4, 14, 17, 3, 17, 18, 1, 18],
#  [9, 7, 9, 10, 1, 10, 11, 5, 11, 12, 4, 12, 15, 1, 15, 17, 2, 17, 18, 1, 18],
#  [9, 7, 9, 10, 1, 10, 13, 4, 13, 14, 7, 14, 15, 3, 15, 16, 7, 16, 17, 8, 17],
#  [9, 7, 9, 11, 4, 11, 12, 4, 12, 14, 7, 14, 15, 3, 15, 17, 2, 17, 18, 6, 18],
#  [10, 1, 10, 11, 6, 11, 13, 2, 13, 14, 7, 14, 16, 6, 16, 17, 3, 17, 18, 5, 18],
#  [9, 7, 9, 11, 5, 11, 13, 5, 13, 14, 1, 14, 15, 1, 15, 17, 5, 17, 18, 6, 18],
#  [10,
#   1,
#   10,
#   11,
#   4,
#   11,
#   11,
#   5,
#   11,
#   12,
#   6,
#   12,
#   12,
#   6,
#   12,
#   13,
#   5,
#   13,
#   14,
#   1,
#   14,
#   14,
#   8,
#   14,
#   15,
#   3,
#   15,
#   16,
#   7,
#   16,
#   17,
#   2,
#   17,
#   18,
#   4,
#   18],
#  [11, 6, 11, 12, 4, 12, 13, 2, 13, 13, 2, 13, 16, 6, 16, 17, 8, 17, 18, 4, 18],
#  [9,
#   7,
#   9,
#   10,
#   1,
#   10,
#   11,
#   5,
#   11,
#   12,
#   4,
#   12,
#   13,
#   2,
#   13,
#   14,
#   4,
#   14,
#   15,
#   5,
#   15,
#   16,
#   8,
#   16,
#   17,
#   5,
#   17],
#  [9,
#   7,
#   9,
#   10,
#   1,
#   10,
#   11,
#   6,
#   11,
#   12,
#   6,
#   12,
#   13,
#   8,
#   13,
#   14,
#   7,
#   14,
#   16,
#   7,
#   16,
#   17,
#   3,
#   17,
#   18,
#   1,
#   18],
#  [10,
#   1,
#   10,
#   11,
#   6,
#   11,
#   12,
#   1,
#   12,
#   13,
#   4,
#   13,
#   14,
#   8,
#   14,
#   15,
#   3,
#   15,
#   17,
#   3,
#   17,
#   18,
#   1,
#   18],
#  [9,
#   5,
#   9,
#   11,
#   1,
#   11,
#   11,
#   8,
#   11,
#   12,
#   2,
#   12,
#   13,
#   6,
#   13,
#   14,
#   1,
#   14,
#   14,
#   7,
#   14,
#   15,
#   2,
#   15,
#   16,
#   8,
#   16],
#  [9, 7, 9, 10, 1, 10, 11, 6, 11, 14, 1, 14, 16, 8, 16, 17, 5, 17, 18, 6, 18],
#  [11,
#   6,
#   11,
#   12,
#   6,
#   12,
#   13,
#   4,
#   13,
#   13,
#   5,
#   13,
#   14,
#   8,
#   14,
#   14,
#   8,
#   14,
#   18,
#   5,
#   18,
#   18,
#   5,
#   18],
#  [10,
#   1,
#   10,
#   11,
#   6,
#   11,
#   12,
#   7,
#   12,
#   13,
#   5,
#   13,
#   14,
#   4,
#   14,
#   15,
#   3,
#   15,
#   16,
#   8,
#   16,
#   17,
#   3,
#   17],
#  [9, 7, 9, 10, 1, 10, 11, 6, 11, 12, 4, 12, 13, 5, 13, 14, 1, 14, 15, 3, 15],
#  [9, 7, 9, 10, 1, 10, 11, 4, 11, 13, 2, 13, 14, 1, 14, 15, 1, 15, 17, 8, 17],
#  [9, 7, 9, 10, 1, 10, 11, 5, 11, 13, 8, 13, 14, 4, 14, 15, 1, 15, 17, 8, 17],
#  [9, 7, 9, 10, 1, 10, 11, 5, 11, 12, 6, 12, 13, 4, 13, 16, 7, 16, 17, 5, 17],
#  [10,
#   1,
#   10,
#   11,
#   7,
#   11,
#   12,
#   1,
#   12,
#   13,
#   4,
#   13,
#   13,
#   8,
#   13,
#   14,
#   7,
#   14,
#   15,
#   3,
#   15,
#   17,
#   3,
#   17,
#   18,
#   4,
#   18,
#   18,
#   5,
#   18],
#  [9, 7, 9, 10, 1, 10, 11, 5, 11, 13, 2, 13, 14, 4, 14, 15, 8, 15, 18, 5, 18],
#  [10,
#   1,
#   10,
#   11,
#   5,
#   11,
#   12,
#   6,
#   12,
#   13,
#   5,
#   13,
#   15,
#   5,
#   15,
#   16,
#   8,
#   16,
#   17,
#   5,
#   17,
#   18,
#   1,
#   18],
#  [9,
#   7,
#   9,
#   11,
#   6,
#   11,
#   13,
#   5,
#   13,
#   14,
#   1,
#   14,
#   15,
#   1,
#   15,
#   16,
#   8,
#   16,
#   17,
#   8,
#   17,
#   18,
#   5,
#   18],
#  [9, 7, 9, 10, 1, 10, 12, 4, 12, 13, 8, 13, 14, 7, 14, 15, 8, 15, 16, 6, 16],
#  [9,
#   7,
#   9,
#   10,
#   1,
#   10,
#   11,
#   7,
#   11,
#   12,
#   1,
#   12,
#   12,
#   6,
#   12,
#   13,
#   4,
#   13,
#   14,
#   8,
#   14,
#   18,
#   4,
#   18],
#  [9, 7, 9, 11, 4, 11, 12, 6, 12, 14, 8, 14, 15, 5, 15, 17, 2, 17, 18, 1, 18],
#  [10, 7, 10, 11, 1, 11, 12, 3, 12, 13, 5, 13, 16, 5, 16, 17, 3, 17, 18, 8, 18],
#  [9,
#   7,
#   9,
#   10,
#   1,
#   10,
#   11,
#   7,
#   11,
#   12,
#   1,
#   12,
#   13,
#   2,
#   13,
#   14,
#   7,
#   14,
#   15,
#   3,
#   15,
#   16,
#   7,
#   16],
#  [9, 7, 9, 10, 1, 10, 11, 4, 11, 12, 6, 12, 13, 4, 13, 14, 7, 14, 15, 8, 15],
#  [10,
#   7,
#   10,
#   11,
#   1,
#   11,
#   11,
#   8,
#   11,
#   12,
#   5,
#   12,
#   13,
#   2,
#   13,
#   13,
#   8,
#   13,
#   16,
#   2,
#   16,
#   18,
#   3,
#   18],
#  [9, 7, 9, 11, 4, 11, 12, 4, 12, 13, 4, 13, 16, 7, 16, 17, 2, 17, 18, 5, 18],
#  [9,
#   7,
#   9,
#   10,
#   1,
#   10,
#   11,
#   5,
#   11,
#   13,
#   8,
#   13,
#   14,
#   7,
#   14,
#   14,
#   8,
#   14,
#   15,
#   1,
#   15,
#   16,
#   3,
#   16],
#  [9,
#   7,
#   9,
#   10,
#   1,
#   10,
#   11,
#   7,
#   11,
#   12,
#   6,
#   12,
#   13,
#   4,
#   13,
#   14,
#   1,
#   14,
#   16,
#   6,
#   16,
#   17,
#   2,
#   17,
#   18,
#   5,
#   18],
#  [10, 1, 10, 11, 1, 11, 12, 6, 12, 14, 4, 14, 15, 3, 15, 16, 8, 16, 17, 2, 17],
#  [9,
#   8,
#   9,
#   10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   12,
#   6,
#   12,
#   13,
#   1,
#   13,
#   15,
#   1,
#   15,
#   16,
#   7,
#   16,
#   17,
#   2,
#   17],
#  [9,
#   8,
#   9,
#   10,
#   1,
#   10,
#   12,
#   1,
#   12,
#   13,
#   1,
#   13,
#   14,
#   1,
#   14,
#   15,
#   8,
#   15,
#   16,
#   7,
#   16,
#   17,
#   3,
#   17,
#   18,
#   2,
#   18],
#  [9,
#   8,
#   9,
#   10,
#   1,
#   10,
#   11,
#   3,
#   11,
#   12,
#   1,
#   12,
#   13,
#   5,
#   13,
#   14,
#   1,
#   14,
#   17,
#   7,
#   17,
#   18,
#   7,
#   18],
#  [9, 8, 9, 10, 1, 10, 11, 3, 11, 12, 4, 12, 13, 8, 13, 14, 3, 14, 15, 8, 15],
#  [12, 2, 12, 13, 4, 13, 13, 5, 13, 14, 3, 14, 15, 7, 15, 16, 7, 16, 17, 7, 17],
#  [9, 8, 9, 10, 1, 10, 11, 1, 11, 12, 6, 12, 13, 1, 13, 16, 6, 16, 18, 6, 18],
#  [9,
#   8,
#   9,
#   10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   12,
#   1,
#   12,
#   13,
#   8,
#   13,
#   15,
#   8,
#   15,
#   16,
#   6,
#   16,
#   17,
#   3,
#   17,
#   18,
#   6,
#   18],
#  [9, 8, 9, 10, 1, 10, 13, 8, 13, 14, 1, 14, 15, 8, 15, 17, 8, 17, 18, 7, 18],
#  [9, 8, 9, 10, 1, 10, 11, 1, 11, 14, 4, 14, 15, 1, 15, 16, 4, 16, 18, 7, 18],
#  [9,
#   8,
#   9,
#   10,
#   1,
#   10,
#   11,
#   5,
#   11,
#   12,
#   2,
#   12,
#   13,
#   4,
#   13,
#   16,
#   6,
#   16,
#   17,
#   2,
#   17,
#   18,
#   2,
#   18],
#  [10, 1, 10, 11, 3, 11, 13, 1, 13, 13, 5, 13, 14, 3, 14, 15, 7, 15, 17, 3, 17],
#  [11, 5, 11, 12, 4, 12, 13, 4, 13, 14, 1, 14, 15, 1, 15, 16, 4, 16, 18, 7, 18],
#  [10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   12,
#   6,
#   12,
#   13,
#   8,
#   13,
#   14,
#   3,
#   14,
#   15,
#   7,
#   15,
#   16,
#   4,
#   16,
#   16,
#   6,
#   16,
#   17,
#   2,
#   17,
#   18,
#   6,
#   18],
#  [10, 1, 10, 12, 4, 12, 13, 1, 13, 13, 5, 13, 14, 6, 14, 15, 7, 15, 16, 4, 16],
#  [10, 1, 10, 11, 3, 11, 12, 2, 12, 13, 4, 13, 15, 1, 15, 16, 4, 16, 18, 1, 18],
#  [9, 8, 9, 10, 1, 10, 11, 3, 11, 13, 5, 13, 13, 8, 13, 14, 3, 14, 15, 8, 15],
#  [9, 8, 9, 10, 1, 10, 12, 1, 12, 13, 1, 13, 14, 1, 14, 17, 2, 17, 18, 1, 18],
#  [9, 8, 9, 10, 1, 10, 11, 5, 11, 12, 1, 12, 13, 5, 13, 16, 4, 16, 17, 3, 17],
#  [10, 1, 10, 12, 4, 12, 13, 8, 13, 14, 1, 14, 15, 1, 15, 16, 8, 16, 17, 8, 17],
#  [9, 8, 9, 12, 6, 12, 13, 5, 13, 14, 4, 14, 15, 3, 15, 16, 4, 16, 18, 2, 18],
#  [10, 1, 10, 11, 1, 11, 12, 2, 12, 14, 1, 14, 15, 1, 15, 17, 7, 17, 18, 2, 18],
#  [9, 8, 9, 10, 1, 10, 11, 7, 11, 12, 6, 12, 13, 5, 13, 15, 1, 15, 17, 3, 17],
#  [9,
#   8,
#   9,
#   10,
#   1,
#   10,
#   11,
#   5,
#   11,
#   12,
#   4,
#   12,
#   12,
#   4,
#   12,
#   15,
#   3,
#   15,
#   16,
#   6,
#   16,
#   18,
#   1,
#   18],
#  [9,
#   8,
#   9,
#   10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   12,
#   2,
#   12,
#   14,
#   3,
#   14,
#   16,
#   8,
#   16,
#   17,
#   7,
#   17,
#   18,
#   2,
#   18],
#  [11, 1, 11, 11, 1, 11, 11, 5, 11, 13, 4, 13, 13, 5, 13, 14, 3, 14, 14, 3, 14],
#  [9, 8, 9, 10, 1, 10, 11, 1, 11, 13, 5, 13, 16, 6, 16, 17, 2, 17, 18, 2, 18],
#  [10,
#   1,
#   10,
#   11,
#   5,
#   11,
#   12,
#   1,
#   12,
#   13,
#   8,
#   13,
#   14,
#   4,
#   14,
#   16,
#   7,
#   16,
#   17,
#   3,
#   17,
#   18,
#   1,
#   18],
#  [9, 8, 9, 13, 5, 13, 14, 3, 14, 15, 1, 15, 16, 8, 16, 17, 3, 17, 18, 6, 18],
#  [9, 8, 9, 10, 1, 10, 12, 2, 12, 13, 5, 13, 15, 1, 15, 16, 7, 16, 17, 2, 17],
#  [10, 1, 10, 13, 4, 13, 14, 2, 14, 15, 6, 15, 16, 7, 16, 17, 1, 17, 18, 1, 18],
#  [10, 1, 10, 11, 5, 11, 12, 2, 12, 14, 1, 14, 16, 4, 16, 17, 3, 17, 18, 1, 18],
#  [9,
#   8,
#   9,
#   10,
#   1,
#   10,
#   10,
#   3,
#   10,
#   11,
#   5,
#   11,
#   11,
#   8,
#   11,
#   13,
#   1,
#   13,
#   13,
#   8,
#   13,
#   14,
#   1,
#   14,
#   17,
#   7,
#   17],
#  [9,
#   8,
#   9,
#   10,
#   1,
#   10,
#   11,
#   1,
#   11,
#   12,
#   1,
#   12,
#   12,
#   4,
#   12,
#   13,
#   5,
#   13,
#   13,
#   5,
#   13,
#   14,
#   4,
#   14],
#  [10, 1, 10, 11, 5, 11, 12, 1, 12, 13, 1, 13, 14, 3, 14, 16, 4, 16, 17, 3, 17],
#  [9, 1, 9, 10, 2, 10, 11, 4, 11, 12, 5, 12, 13, 1, 13, 14, 1, 14, 16, 5, 16],
#  [9, 1, 9, 11, 3, 11, 13, 1, 13, 14, 1, 14, 15, 8, 15, 16, 8, 16, 17, 1, 17],
#  [9,
#   1,
#   9,
#   11,
#   3,
#   11,
#   12,
#   2,
#   12,
#   13,
#   1,
#   13,
#   14,
#   6,
#   14,
#   15,
#   6,
#   15,
#   16,
#   4,
#   16,
#   18,
#   7,
#   18],
#  [9,
#   1,
#   9,
#   10,
#   2,
#   10,
#   11,
#   6,
#   11,
#   12,
#   3,
#   12,
#   13,
#   1,
#   13,
#   14,
#   3,
#   14,
#   15,
#   4,
#   15,
#   17,
#   1,
#   17,
#   18,
#   4,
#   18],
#  [9,
#   1,
#   9,
#   10,
#   2,
#   10,
#   11,
#   4,
#   11,
#   12,
#   3,
#   12,
#   13,
#   2,
#   13,
#   14,
#   3,
#   14,
#   15,
#   3,
#   15,
#   16,
#   4,
#   16,
#   17,
#   1,
#   17,
#   18,
#   8,
#   18],
#  [11, 3, 11, 12, 5, 12, 13, 1, 13, 14, 1, 14, 16, 8, 16, 17, 4, 17, 18, 5, 18],
#  [9, 1, 9, 10, 2, 10, 12, 5, 12, 13, 1, 13, 16, 5, 16, 17, 2, 17, 18, 4, 18],
#  [9,
#   1,
#   9,
#   10,
#   2,
#   10,
#   11,
#   3,
#   11,
#   12,
#   5,
#   12,
#   13,
#   1,
#   13,
#   14,
#   3,
#   14,
#   17,
#   2,
#   17,
#   18,
#   7,
#   18],
#  [9,
#   1,
#   9,
#   11,
#   4,
#   11,
#   12,
#   3,
#   12,
#   13,
#   3,
#   13,
#   14,
#   6,
#   14,
#   15,
#   8,
#   15,
#   16,
#   8,
#   16,
#   17,
#   1,
#   17,
#   18,
#   7,
#   18],
#  [10,
#   2,
#   10,
#   10,
#   2,
#   10,
#   11,
#   2,
#   11,
#   12,
#   2,
#   12,
#   12,
#   5,
#   12,
#   13,
#   1,
#   13,
#   13,
#   8,
#   13,
#   14,
#   1,
#   14,
#   16,
#   1,
#   16,
#   17,
#   4,
#   17,
#   18,
#   4,
#   18],
#  [9, 1, 9, 10, 2, 10, 11, 4, 11, 12, 8, 12, 13, 8, 13, 14, 6, 14, 15, 6, 15],
#  [10, 2, 10, 11, 2, 11, 12, 3, 12, 13, 3, 13, 14, 6, 14, 15, 4, 15, 16, 1, 16],
#  [9, 1, 9, 10, 2, 10, 11, 4, 11, 14, 6, 14, 16, 4, 16, 16, 8, 16, 17, 4, 17],
#  [9,
#   1,
#   9,
#   11,
#   6,
#   11,
#   13,
#   1,
#   13,
#   14,
#   3,
#   14,
#   15,
#   3,
#   15,
#   16,
#   8,
#   16,
#   17,
#   4,
#   17,
#   18,
#   4,
#   18],
#  [9,
#   1,
#   9,
#   10,
#   2,
#   10,
#   11,
#   6,
#   11,
#   12,
#   2,
#   12,
#   13,
#   8,
#   13,
#   14,
#   2,
#   14,
#   15,
#   3,
#   15,
#   17,
#   8,
#   17],
#  [9,
#   1,
#   9,
#   12,
#   5,
#   12,
#   13,
#   8,
#   13,
#   14,
#   2,
#   14,
#   15,
#   4,
#   15,
#   16,
#   4,
#   16,
#   17,
#   1,
#   17,
#   18,
#   8,
#   18],
#  [10, 2, 10, 13, 2, 13, 14, 2, 14, 14, 2, 14, 16, 4, 16, 17, 2, 17, 18, 8, 18],
#  [9,
#   1,
#   9,
#   10,
#   2,
#   10,
#   11,
#   2,
#   11,
#   11,
#   3,
#   11,
#   11,
#   6,
#   11,
#   13,
#   2,
#   13,
#   13,
#   3,
#   13,
#   13,
#   3,
#   13],
#  [9, 1, 9, 10, 2, 10, 11, 4, 11, 12, 5, 12, 13, 1, 13, 14, 1, 14, 18, 8, 18],
#  [10, 2, 10, 11, 2, 11, 12, 5, 12, 13, 3, 13, 14, 3, 14, 16, 4, 16, 18, 4, 18],
#  [9,
#   1,
#   9,
#   9,
#   1,
#   9,
#   10,
#   2,
#   10,
#   10,
#   2,
#   10,
#   11,
#   3,
#   11,
#   11,
#   6,
#   11,
#   12,
#   3,
#   12,
#   12,
#   5,
#   12],
#  [11, 3, 11, 12, 3, 12, 12, 5, 12, 13, 8, 13, 14, 3, 14, 15, 3, 15, 16, 4, 16],
#  [9,
#   1,
#   9,
#   10,
#   2,
#   10,
#   11,
#   4,
#   11,
#   12,
#   8,
#   12,
#   13,
#   1,
#   13,
#   15,
#   3,
#   15,
#   16,
#   4,
#   16,
#   17,
#   1,
#   17],
#  [9,
#   1,
#   9,
#   10,
#   2,
#   10,
#   11,
#   4,
#   11,
#   12,
#   3,
#   12,
#   12,
#   8,
#   12,
#   13,
#   3,
#   13,
#   13,
#   8,
#   13,
#   14,
#   3,
#   14,
#   15,
#   4,
#   15],
#  [9, 1, 9, 11, 3, 11, 12, 2, 12, 13, 8, 13, 15, 4, 15, 16, 8, 16, 17, 2, 17],
#  [9, 1, 9, 10, 2, 10, 12, 3, 12, 13, 8, 13, 14, 2, 14, 15, 8, 15, 17, 4, 17],
#  [9, 1, 9, 11, 3, 11, 12, 5, 12, 13, 8, 13, 14, 1, 14, 17, 1, 17, 18, 5, 18],
#  [9, 1, 9, 11, 6, 11, 12, 3, 12, 13, 3, 13, 14, 1, 14, 15, 8, 15, 17, 1, 17],
#  [10,
#   2,
#   10,
#   11,
#   6,
#   11,
#   12,
#   8,
#   12,
#   13,
#   8,
#   13,
#   14,
#   3,
#   14,
#   16,
#   4,
#   16,
#   17,
#   1,
#   17,
#   18,
#   5,
#   18],
#  [9,
#   1,
#   9,
#   10,
#   2,
#   10,
#   11,
#   3,
#   11,
#   12,
#   3,
#   12,
#   13,
#   2,
#   13,
#   16,
#   1,
#   16,
#   17,
#   8,
#   17,
#   18,
#   4,
#   18],
#  [9,
#   1,
#   9,
#   10,
#   2,
#   10,
#   11,
#   4,
#   11,
#   12,
#   5,
#   12,
#   13,
#   3,
#   13,
#   14,
#   1,
#   14,
#   15,
#   8,
#   15,
#   17,
#   1,
#   17,
#   18,
#   8,
#   18],
#  [9, 1, 9, 11, 4, 11, 12, 3, 12, 13, 2, 13, 14, 1, 14, 15, 8, 15, 15, 8, 15],
#  [10, 2, 10, 10, 2, 10, 11, 2, 11, 11, 4, 11, 12, 8, 12, 13, 8, 13, 16, 8, 16],
#  [9,
#   1,
#   9,
#   10,
#   2,
#   10,
#   11,
#   6,
#   11,
#   12,
#   5,
#   12,
#   13,
#   8,
#   13,
#   14,
#   6,
#   14,
#   15,
#   8,
#   15,
#   17,
#   8,
#   17,
#   18,
#   7,
#   18],
#  [9, 2, 9, 10, 2, 10, 12, 3, 12, 14, 4, 14, 15, 7, 15, 17, 3, 17, 18, 5, 18],
#  [9,
#   2,
#   9,
#   11,
#   2,
#   11,
#   13,
#   7,
#   13,
#   14,
#   7,
#   14,
#   15,
#   2,
#   15,
#   15,
#   3,
#   15,
#   16,
#   2,
#   16,
#   16,
#   3,
#   16,
#   18,
#   7,
#   18],
#  [9, 2, 9, 10, 2, 10, 13, 8, 13, 14, 4, 14, 15, 1, 15, 17, 3, 17, 18, 5, 18],
#  [9, 2, 9, 10, 2, 10, 11, 7, 11, 12, 3, 12, 13, 2, 13, 14, 1, 14, 15, 1, 15],
#  [9,
#   2,
#   9,
#   10,
#   2,
#   10,
#   11,
#   2,
#   11,
#   12,
#   1,
#   12,
#   14,
#   1,
#   14,
#   15,
#   1,
#   15,
#   17,
#   3,
#   17,
#   18,
#   7,
#   18],
#  [9, 2, 9, 10, 2, 10, 12, 5, 12, 13, 7, 13, 16, 3, 16, 17, 3, 17, 18, 7, 18],
#  [9, 2, 9, 11, 7, 11, 12, 4, 12, 13, 5, 13, 15, 3, 15, 17, 5, 17, 18, 7, 18],
#  [9, 2, 9, 10, 2, 10, 12, 1, 12, 14, 5, 14, 15, 3, 15, 16, 3, 16, 18, 1, 18],
#  [9,
#   2,
#   9,
#   10,
#   2,
#   10,
#   11,
#   4,
#   11,
#   13,
#   5,
#   13,
#   15,
#   1,
#   15,
#   16,
#   2,
#   16,
#   17,
#   1,
#   17,
#   18,
#   1,
#   18],
#  [10,
#   2,
#   10,
#   11,
#   2,
#   11,
#   12,
#   1,
#   12,
#   12,
#   3,
#   12,
#   13,
#   5,
#   13,
#   14,
#   5,
#   14,
#   14,
#   5,
#   14,
#   17,
#   5,
#   17],
#  [9,
#   2,
#   9,
#   10,
#   2,
#   10,
#   11,
#   7,
#   11,
#   12,
#   1,
#   12,
#   13,
#   8,
#   13,
#   14,
#   4,
#   14,
#   15,
#   3,
#   15,
#   17,
#   3,
#   17,
#   18,
#   1,
#   18],
#  [12, 5, 12, 13, 7, 13, 14, 1, 14, 16, 3, 16, 17, 1, 17, 17, 7, 17, 18, 1, 18],
#  [9, 2, 9, 10, 2, 10, 11, 4, 11, 12, 1, 12, 14, 7, 14, 17, 5, 17, 18, 7, 18],
#  [10, 2, 10, 11, 3, 11, 12, 5, 12, 13, 2, 13, 14, 7, 14, 15, 2, 15, 16, 3, 16],
#  [9, 2, 9, 10, 2, 10, 12, 3, 12, 13, 5, 13, 14, 5, 14, 15, 3, 15, 17, 5, 17],
#  [11, 4, 11, 13, 8, 13, 14, 1, 14, 15, 3, 15, 16, 3, 16, 17, 5, 17, 18, 5, 18],
#  [11,
#   4,
#   11,
#   12,
#   3,
#   12,
#   13,
#   2,
#   13,
#   14,
#   4,
#   14,
#   15,
#   7,
#   15,
#   16,
#   1,
#   16,
#   17,
#   7,
#   17,
#   18,
#   2,
#   18],
#  [10, 2, 10, 11, 7, 11, 13, 3, 13, 14, 1, 14, 14, 2, 14, 15, 6, 15, 18, 1, 18],
#  [9, 2, 9, 10, 2, 10, 11, 3, 11, 12, 4, 12, 13, 7, 13, 14, 1, 14, 17, 3, 17],
#  [9, 2, 9, 10, 2, 10, 11, 7, 11, 12, 1, 12, 13, 5, 13, 14, 1, 14, 18, 5, 18],
#  [9, 2, 9, 10, 2, 10, 11, 4, 11, 12, 1, 12, 13, 7, 13, 15, 7, 15, 17, 7, 17],
#  [10,
#   2,
#   10,
#   11,
#   3,
#   11,
#   12,
#   3,
#   12,
#   13,
#   5,
#   13,
#   15,
#   7,
#   15,
#   16,
#   8,
#   16,
#   17,
#   5,
#   17,
#   18,
#   7,
#   18],
#  [9, 2, 9, 11, 3, 11, 13, 8, 13, 14, 4, 14, 15, 1, 15, 17, 5, 17, 18, 7, 18],
#  [9,
#   2,
#   9,
#   10,
#   2,
#   10,
#   11,
#   7,
#   11,
#   13,
#   2,
#   13,
#   14,
#   1,
#   14,
#   15,
#   2,
#   15,
#   17,
#   7,
#   17,
#   18,
#   2,
#   18],
#  [9, 2, 9, 10, 2, 10, 12, 5, 12, 13, 2, 13, 15, 1, 15, 16, 3, 16, 17, 1, 17],
#  [9, 2, 9, 11, 2, 11, 12, 5, 12, 14, 5, 14, 15, 1, 15, 16, 3, 16, 17, 1, 17],
#  [9,
#   2,
#   9,
#   10,
#   2,
#   10,
#   11,
#   4,
#   11,
#   12,
#   5,
#   12,
#   13,
#   8,
#   13,
#   14,
#   4,
#   14,
#   15,
#   1,
#   15,
#   18,
#   7,
#   18],
#  [11, 3, 11, 12, 5, 12, 13, 5, 13, 15, 2, 15, 16, 8, 16, 17, 3, 17, 18, 7, 18],
#  [9,
#   2,
#   9,
#   11,
#   2,
#   11,
#   12,
#   1,
#   12,
#   14,
#   5,
#   14,
#   15,
#   1,
#   15,
#   16,
#   8,
#   16,
#   17,
#   3,
#   17,
#   18,
#   7,
#   18],
#  [10, 2, 10, 11, 7, 11, 12, 3, 12, 13, 8, 13, 14, 4, 14, 15, 1, 15, 16, 1, 16],
#  [9, 2, 9, 10, 2, 10, 10, 2, 10, 11, 2, 11, 13, 2, 13, 14, 5, 14, 15, 1, 15],
#  [9, 2, 9, 10, 2, 10, 13, 8, 13, 14, 4, 14, 15, 7, 15, 17, 1, 17, 18, 1, 18],
#  [9, 2, 9, 12, 1, 12, 13, 7, 13, 14, 4, 14, 15, 7, 15, 16, 2, 16, 18, 5, 18],
#  [10, 2, 10, 11, 2, 11, 12, 5, 12, 13, 5, 13, 14, 1, 14, 15, 3, 15, 17, 7, 17],
#  [10,
#   2,
#   10,
#   13,
#   5,
#   13,
#   14,
#   4,
#   14,
#   14,
#   4,
#   14,
#   15,
#   2,
#   15,
#   15,
#   3,
#   15,
#   16,
#   8,
#   16,
#   17,
#   5,
#   17,
#   18,
#   1,
#   18],
#  [9, 3, 9, 10, 2, 10, 11, 5, 11, 12, 4, 12, 13, 4, 13, 15, 4, 15, 17, 5, 17],
#  [9, 3, 9, 10, 2, 10, 12, 2, 12, 13, 6, 13, 14, 8, 14, 15, 4, 15, 17, 8, 17],
#  [9, 3, 9, 10, 2, 10, 11, 3, 11, 13, 1, 13, 15, 8, 15, 16, 6, 16, 17, 8, 17],
#  [9, 3, 9, 10, 2, 10, 11, 6, 11, 12, 2, 12, 13, 6, 13, 14, 8, 14, 15, 4, 15],
#  [9, 3, 9, 10, 2, 10, 10, 2, 10, 11, 3, 11, 11, 5, 11, 12, 2, 12, 15, 8, 15],
#  [9, 3, 9, 10, 2, 10, 11, 3, 11, 12, 3, 12, 13, 3, 13, 14, 3, 14, 15, 4, 15],
#  [9,
#   3,
#   9,
#   10,
#   2,
#   10,
#   11,
#   7,
#   11,
#   12,
#   3,
#   12,
#   13,
#   6,
#   13,
#   15,
#   6,
#   15,
#   16,
#   8,
#   16,
#   18,
#   5,
#   18],
#  [9, 3, 9, 10, 2, 10, 11, 3, 11, 12, 3, 12, 12, 3, 12, 13, 6, 13, 15, 4, 15],
#  [9, 3, 9, 10, 2, 10, 11, 5, 11, 13, 1, 13, 15, 8, 15, 17, 2, 17, 18, 2, 18],
#  [9, 3, 9, 10, 2, 10, 12, 4, 12, 13, 3, 13, 14, 2, 14, 16, 8, 16, 17, 5, 17],
#  [9,
#   3,
#   9,
#   10,
#   2,
#   10,
#   11,
#   6,
#   11,
#   12,
#   3,
#   12,
#   13,
#   1,
#   13,
#   14,
#   8,
#   14,
#   15,
#   8,
#   15,
#   16,
#   6,
#   16,
#   17,
#   2,
#   17],
#  [9, 3, 9, 10, 2, 10, 11, 6, 11, 12, 2, 12, 15, 6, 15, 16, 8, 16, 17, 6, 17],
#  [9, 3, 9, 10, 2, 10, 12, 8, 12, 13, 1, 13, 14, 8, 14, 15, 4, 15, 17, 8, 17],
#  [9,
#   3,
#   9,
#   10,
#   2,
#   10,
#   11,
#   3,
#   11,
#   12,
#   3,
#   12,
#   14,
#   3,
#   14,
#   15,
#   4,
#   15,
#   16,
#   5,
#   16,
#   17,
#   6,
#   17],
#  [11, 3, 11, 12, 8, 12, 13, 3, 13, 14, 7, 14, 15, 1, 15, 17, 6, 17, 18, 3, 18],
#  [9, 3, 9, 10, 2, 10, 11, 6, 11, 13, 4, 13, 14, 7, 14, 16, 6, 16, 17, 8, 17],
#  [9, 3, 9, 10, 2, 10, 11, 7, 11, 12, 2, 12, 13, 3, 13, 15, 8, 15, 17, 6, 17],
#  [10, 2, 10, 11, 3, 11, 13, 4, 13, 14, 3, 14, 15, 8, 15, 16, 6, 16, 17, 5, 17],
#  [9, 3, 9, 11, 5, 11, 12, 2, 12, 14, 3, 14, 15, 8, 15, 17, 8, 17, 18, 3, 18],
#  [10, 2, 10, 11, 5, 11, 13, 1, 13, 14, 8, 14, 15, 1, 15, 16, 8, 16, 17, 6, 17],
#  [9,
#   3,
#   9,
#   10,
#   2,
#   10,
#   12,
#   8,
#   12,
#   13,
#   3,
#   13,
#   14,
#   8,
#   14,
#   15,
#   1,
#   15,
#   16,
#   3,
#   16,
#   18,
#   2,
#   18],
#  [10, 2, 10, 11, 7, 11, 12, 4, 12, 14, 8, 14, 16, 3, 16, 17, 6, 17, 18, 5, 18],
#  [10,
#   2,
#   10,
#   11,
#   7,
#   11,
#   12,
#   4,
#   12,
#   13,
#   6,
#   13,
#   14,
#   2,
#   14,
#   15,
#   6,
#   15,
#   16,
#   6,
#   16,
#   18,
#   2,
#   18],
#  [10, 2, 10, 11, 3, 11, 12, 3, 12, 14, 2, 14, 16, 8, 16, 17, 6, 17, 18, 3, 18],
#  [9, 3, 9, 10, 2, 10, 11, 3, 11, 13, 6, 13, 15, 4, 15, 17, 6, 17, 18, 5, 18],
#  [9, 3, 9, 10, 2, 10, 11, 5, 11, 13, 3, 13, 14, 3, 14, 15, 6, 15, 16, 8, 16],
#  [9, 3, 9, 10, 2, 10, 12, 2, 12, 14, 8, 14, 15, 6, 15, 17, 5, 17, 18, 8, 18],
#  [11, 5, 11, 12, 8, 12, 13, 4, 13, 14, 3, 14, 15, 8, 15, 17, 6, 17, 18, 2, 18],
#  [10, 2, 10, 11, 3, 11, 13, 3, 13, 14, 2, 14, 15, 1, 15, 16, 3, 16, 18, 8, 18],
#  [9, 3, 9, 10, 2, 10, 13, 4, 13, 13, 6, 13, 14, 7, 14, 15, 8, 15, 16, 6, 16],
#  [9,
#   3,
#   9,
#   11,
#   4,
#   11,
#   13,
#   4,
#   13,
#   14,
#   3,
#   14,
#   14,
#   5,
#   14,
#   15,
#   4,
#   15,
#   16,
#   3,
#   16,
#   17,
#   4,
#   17],
#  [9, 4, 9, 10, 2, 10, 11, 2, 11, 14, 5, 14, 15, 6, 15, 16, 8, 16, 17, 5, 17],
#  [9,
#   4,
#   9,
#   10,
#   2,
#   10,
#   11,
#   5,
#   11,
#   12,
#   3,
#   12,
#   13,
#   6,
#   13,
#   13,
#   7,
#   13,
#   14,
#   4,
#   14,
#   15,
#   1,
#   15,
#   16,
#   8,
#   16],
#  [11,
#   1,
#   11,
#   11,
#   4,
#   11,
#   12,
#   4,
#   12,
#   13,
#   1,
#   13,
#   13,
#   5,
#   13,
#   14,
#   6,
#   14,
#   16,
#   5,
#   16,
#   17,
#   2,
#   17,
#   18,
#   4,
#   18],
#  [10, 2, 10, 11, 1, 11, 12, 2, 12, 13, 6, 13, 16, 3, 16, 17, 5, 17, 18, 6, 18],
#  [9, 4, 9, 11, 1, 11, 13, 1, 13, 14, 5, 14, 15, 7, 15, 16, 8, 16, 18, 4, 18],
#  [9, 4, 9, 10, 2, 10, 13, 6, 13, 15, 1, 15, 16, 8, 16, 17, 8, 17, 18, 1, 18],
#  [9, 4, 9, 13, 7, 13, 14, 5, 14, 15, 3, 15, 16, 3, 16, 17, 2, 17, 18, 7, 18],
#  [11,
#   4,
#   11,
#   12,
#   7,
#   12,
#   13,
#   2,
#   13,
#   14,
#   5,
#   14,
#   14,
#   5,
#   14,
#   15,
#   2,
#   15,
#   16,
#   8,
#   16,
#   17,
#   5,
#   17],
#  [9,
#   4,
#   9,
#   10,
#   2,
#   10,
#   11,
#   5,
#   11,
#   12,
#   7,
#   12,
#   14,
#   5,
#   14,
#   15,
#   6,
#   15,
#   16,
#   3,
#   16,
#   17,
#   5,
#   17],
#  [9, 4, 9, 11, 1, 11, 12, 4, 12, 13, 7, 13, 14, 4, 14, 15, 6, 15, 17, 2, 17],
#  [9,
#   4,
#   9,
#   11,
#   1,
#   11,
#   12,
#   7,
#   12,
#   13,
#   2,
#   13,
#   14,
#   7,
#   14,
#   15,
#   7,
#   15,
#   17,
#   2,
#   17,
#   18,
#   1,
#   18],
#  [9, 4, 9, 10, 2, 10, 11, 8, 11, 12, 4, 12, 13, 7, 13, 14, 2, 14, 16, 3, 16],
#  [9, 4, 9, 11, 5, 11, 12, 7, 12, 14, 2, 14, 15, 7, 15, 17, 8, 17, 18, 1, 18],
#  [9, 4, 9, 10, 2, 10, 11, 5, 11, 12, 7, 12, 13, 1, 13, 15, 1, 15, 17, 8, 17],
#  [9, 4, 9, 11, 1, 11, 13, 2, 13, 14, 4, 14, 16, 1, 16, 17, 7, 17, 18, 1, 18],
#  [10, 2, 10, 11, 2, 11, 12, 4, 12, 13, 6, 13, 14, 7, 14, 15, 1, 15, 18, 6, 18],
#  [9,
#   4,
#   9,
#   10,
#   2,
#   10,
#   11,
#   8,
#   11,
#   13,
#   1,
#   13,
#   14,
#   7,
#   14,
#   15,
#   1,
#   15,
#   17,
#   5,
#   17,
#   18,
#   1,
#   18],
#  [10, 2, 10, 11, 2, 11, 12, 7, 12, 13, 7, 13, 16, 1, 16, 17, 7, 17, 18, 4, 18],
#  [9,
#   4,
#   9,
#   10,
#   2,
#   10,
#   11,
#   5,
#   11,
#   12,
#   3,
#   12,
#   13,
#   7,
#   13,
#   14,
#   2,
#   14,
#   15,
#   3,
#   15,
#   16,
#   3,
#   16],
#  [10, 2, 10, 11, 5, 11, 12, 2, 12, 14, 5, 14, 16, 2, 16, 17, 5, 17, 18, 7, 18],
#  [13,
#   6,
#   13,
#   14,
#   6,
#   14,
#   14,
#   6,
#   14,
#   15,
#   8,
#   15,
#   15,
#   8,
#   15,
#   16,
#   8,
#   16,
#   17,
#   5,
#   17,
#   18,
#   4,
#   18],
#  [9, 4, 9, 10, 2, 10, 11, 8, 11, 14, 2, 14, 15, 1, 15, 17, 2, 17, 18, 1, 18],
#  [9, 4, 9, 11, 1, 11, 12, 3, 12, 12, 4, 12, 14, 2, 14, 17, 7, 17, 18, 7, 18],
#  [10, 2, 10, 12, 4, 12, 12, 6, 12, 13, 7, 13, 14, 6, 14, 15, 1, 15, 16, 5, 16],
#  [10,
#   2,
#   10,
#   12,
#   5,
#   12,
#   13,
#   5,
#   13,
#   14,
#   1,
#   14,
#   14,
#   3,
#   14,
#   15,
#   6,
#   15,
#   16,
#   8,
#   16,
#   17,
#   5,
#   17,
#   18,
#   4,
#   18],
#  [9, 5, 9, 11, 3, 11, 12, 5, 12, 13, 6, 13, 14, 4, 14, 15, 6, 15, 16, 1, 16],
#  [9,
#   5,
#   9,
#   10,
#   2,
#   10,
#   11,
#   3,
#   11,
#   12,
#   5,
#   12,
#   13,
#   4,
#   13,
#   14,
#   1,
#   14,
#   15,
#   4,
#   15,
#   16,
#   3,
#   16,
#   17,
#   5,
#   17,
#   18,
#   2,
#   18],
#  [9,
#   5,
#   9,
#   11,
#   4,
#   11,
#   12,
#   7,
#   12,
#   13,
#   5,
#   13,
#   14,
#   3,
#   14,
#   15,
#   4,
#   15,
#   16,
#   8,
#   16,
#   17,
#   5,
#   17,
#   18,
#   2,
#   18],
#  [9, 5, 9, 10, 2, 10, 11, 3, 11, 12, 5, 12, 13, 5, 13, 14, 8, 14, 15, 6, 15],
#  [10, 2, 10, 11, 2, 11, 12, 8, 12, 13, 4, 13, 15, 7, 15, 16, 3, 16, 18, 2, 18],
#  [9, 5, 9, 10, 2, 10, 11, 5, 11, 12, 8, 12, 13, 4, 13, 14, 3, 14, 16, 4, 16],
#  [9,
#   5,
#   9,
#   11,
#   5,
#   11,
#   13,
#   4,
#   13,
#   14,
#   3,
#   14,
#   15,
#   7,
#   15,
#   16,
#   1,
#   16,
#   17,
#   5,
#   17,
#   18,
#   4,
#   18],
#  [9, 5, 9, 10, 2, 10, 12, 5, 12, 13, 4, 13, 14, 3, 14, 17, 4, 17, 18, 2, 18],
#  [11, 5, 11, 11, 7, 11, 12, 2, 12, 14, 2, 14, 15, 7, 15, 16, 7, 16, 18, 7, 18],
#  [10, 2, 10, 11, 2, 11, 12, 5, 12, 13, 3, 13, 15, 4, 15, 16, 8, 16, 18, 7, 18],
#  [11, 5, 11, 12, 2, 12, 13, 5, 13, 14, 8, 14, 16, 8, 16, 17, 5, 17, 18, 2, 18],
#  [9,
#   5,
#   9,
#   10,
#   2,
#   10,
#   11,
#   5,
#   11,
#   13,
#   6,
#   13,
#   14,
#   3,
#   14,
#   15,
#   7,
#   15,
#   16,
#   3,
#   16,
#   18,
#   2,
#   18],
#  [9,
#   5,
#   9,
#   10,
#   2,
#   10,
#   11,
#   4,
#   11,
#   13,
#   4,
#   13,
#   14,
#   1,
#   14,
#   15,
#   6,
#   15,
#   16,
#   4,
#   16,
#   17,
#   1,
#   17],
#  [9, 5, 9, 11, 4, 11, 12, 2, 12, 13, 4, 13, 14, 4, 14, 16, 4, 16, 18, 4, 18],
#  [9,
#   2,
#   9,
#   9,
#   5,
#   9,
#   10,
#   2,
#   10,
#   10,
#   8,
#   10,
#   11,
#   5,
#   11,
#   12,
#   3,
#   12,
#   13,
#   4,
#   13,
#   14,
#   8,
#   14,
#   15,
#   7,
#   15,
#   17,
#   8,
#   17],
#  [9,
#   5,
#   9,
#   10,
#   2,
#   10,
#   11,
#   4,
#   11,
#   12,
#   2,
#   12,
#   13,
#   4,
#   13,
#   14,
#   3,
#   14,
#   17,
#   5,
#   17,
#   18,
#   2,
#   18],
#  [9,
#   5,
#   9,
#   10,
#   2,
#   10,
#   11,
#   3,
#   11,
#   12,
#   2,
#   12,
#   13,
#   3,
#   13,
#   14,
#   1,
#   14,
#   15,
#   4,
#   15,
#   18,
#   7,
#   18],
#  [9, 5, 9, 10, 2, 10, 12, 8, 12, 13, 3, 13, 15, 4, 15, 16, 3, 16, 17, 8, 17],
#  [9,
#   5,
#   9,
#   10,
#   2,
#   10,
#   11,
#   4,
#   11,
#   13,
#   4,
#   13,
#   14,
#   1,
#   14,
#   15,
#   3,
#   15,
#   16,
#   3,
#   16,
#   17,
#   1,
#   17,
#   18,
#   2,
#   18],
#  [9,
#   5,
#   9,
#   10,
#   2,
#   10,
#   10,
#   2,
#   10,
#   11,
#   5,
#   11,
#   12,
#   8,
#   12,
#   13,
#   5,
#   13,
#   14,
#   3,
#   14,
#   15,
#   6,
#   15,
#   16,
#   1,
#   16,
#   17,
#   1,
#   17],
#  [9, 5, 9, 10, 2, 10, 11, 4, 11, 13, 6, 13, 14, 3, 14, 15, 4, 15, 17, 8, 17],
#  [9, 5, 9, 12, 5, 12, 12, 7, 12, 13, 3, 13, 13, 5, 13, 14, 4, 14, 14, 4, 14],
#  [10, 2, 10, 11, 3, 11, 12, 2, 12, 13, 6, 13, 14, 3, 14, 16, 8, 16, 17, 5, 17],
#  [11, 7, 11, 12, 4, 12, 13, 5, 13, 14, 3, 14, 16, 5, 16, 17, 2, 17, 18, 2, 18],
#  [9,
#   6,
#   9,
#   10,
#   2,
#   10,
#   11,
#   5,
#   11,
#   12,
#   5,
#   12,
#   13,
#   5,
#   13,
#   15,
#   4,
#   15,
#   16,
#   6,
#   16,
#   18,
#   2,
#   18],
#  [9,
#   6,
#   9,
#   10,
#   2,
#   10,
#   11,
#   8,
#   11,
#   12,
#   4,
#   12,
#   13,
#   4,
#   13,
#   15,
#   4,
#   15,
#   17,
#   4,
#   17,
#   18,
#   5,
#   18],
#  [9, 6, 9, 10, 2, 10, 11, 5, 11, 12, 4, 12, 13, 4, 13, 15, 4, 15, 17, 7, 17],
#  [9, 6, 9, 10, 2, 10, 11, 1, 11, 12, 4, 12, 15, 6, 15, 16, 5, 16, 17, 1, 17],
#  [9, 6, 9, 10, 2, 10, 11, 5, 11, 12, 5, 12, 13, 5, 13, 14, 3, 14, 15, 6, 15],
#  [9,
#   6,
#   9,
#   10,
#   2,
#   10,
#   11,
#   1,
#   11,
#   13,
#   2,
#   13,
#   14,
#   1,
#   14,
#   15,
#   4,
#   15,
#   16,
#   4,
#   16,
#   18,
#   4,
#   18],
#  [10, 2, 10, 11, 1, 11, 13, 4, 13, 14, 1, 14, 15, 6, 15, 17, 1, 17, 18, 5, 18],
#  [9,
#   6,
#   9,
#   10,
#   2,
#   10,
#   12,
#   5,
#   12,
#   13,
#   5,
#   13,
#   14,
#   5,
#   14,
#   15,
#   8,
#   15,
#   16,
#   6,
#   16,
#   17,
#   1,
#   17],
#  [9,
#   6,
#   9,
#   10,
#   2,
#   10,
#   10,
#   2,
#   10,
#   11,
#   5,
#   11,
#   11,
#   8,
#   11,
#   12,
#   3,
#   12,
#   12,
#   8,
#   12,
#   13,
#   2,
#   13,
#   13,
#   8,
#   13,
#   14,
#   4,
#   14],
#  [9, 6, 9, 11, 1, 11, 12, 3, 12, 13, 8, 13, 14, 4, 14, 17, 7, 17, 18, 2, 18],
#  [10, 2, 10, 11, 8, 11, 12, 4, 12, 13, 8, 13, 14, 5, 14, 16, 4, 16, 18, 5, 18],
#  [9,
#   6,
#   9,
#   10,
#   2,
#   10,
#   11,
#   5,
#   11,
#   12,
#   8,
#   12,
#   13,
#   4,
#   13,
#   14,
#   5,
#   14,
#   15,
#   6,
#   15,
#   16,
#   5,
#   16],
#  [9,
#   6,
#   9,
#   11,
#   8,
#   11,
#   13,
#   5,
#   13,
#   14,
#   1,
#   14,
#   15,
#   4,
#   15,
#   16,
#   5,
#   16,
#   17,
#   7,
#   17,
#   18,
#   5,
#   18],
#  [10,
#   2,
#   10,
#   11,
#   5,
#   11,
#   12,
#   3,
#   12,
#   13,
#   4,
#   13,
#   14,
#   5,
#   14,
#   15,
#   4,
#   15,
#   16,
#   6,
#   16,
#   18,
#   5,
#   18],
#  [10, 2, 10, 11, 5, 11, 12, 5, 12, 13, 4, 13, 14, 4, 14, 15, 4, 15, 16, 5, 16],
#  [9, 6, 9, 10, 2, 10, 11, 1, 11, 12, 4, 12, 12, 8, 12, 13, 2, 13, 15, 7, 15],
#  [9, 6, 9, 11, 8, 11, 12, 8, 12, 14, 4, 14, 15, 8, 15, 16, 7, 16, 17, 1, 17],
#  [9, 6, 9, 10, 2, 10, 13, 5, 13, 14, 3, 14, 15, 4, 15, 16, 6, 16, 17, 7, 17],
#  [10, 2, 10, 11, 8, 11, 12, 8, 12, 13, 8, 13, 14, 4, 14, 15, 6, 15, 16, 4, 16],
#  [10,
#   2,
#   10,
#   11,
#   8,
#   11,
#   12,
#   3,
#   12,
#   12,
#   3,
#   12,
#   13,
#   5,
#   13,
#   15,
#   4,
#   15,
#   16,
#   5,
#   16,
#   17,
#   2,
#   17],
#  [10, 2, 10, 11, 5, 11, 14, 3, 14, 15, 8, 15, 16, 6, 16, 17, 7, 17, 18, 2, 18],
#  [9, 7, 9, 10, 2, 10, 11, 3, 11, 13, 6, 13, 14, 7, 14, 17, 6, 17, 18, 4, 18],
#  [11, 3, 11, 11, 7, 11, 12, 1, 12, 12, 3, 12, 14, 7, 14, 15, 2, 15, 18, 7, 18],
#  [9,
#   7,
#   9,
#   10,
#   2,
#   10,
#   11,
#   7,
#   11,
#   12,
#   7,
#   12,
#   13,
#   4,
#   13,
#   14,
#   2,
#   14,
#   17,
#   6,
#   17,
#   18,
#   6,
#   18],
#  [9, 7, 9, 10, 2, 10, 13, 6, 13, 15, 3, 15, 16, 7, 16, 17, 5, 17, 18, 7, 18],
#  [9,
#   7,
#   9,
#   10,
#   2,
#   10,
#   13,
#   6,
#   13,
#   15,
#   7,
#   15,
#   16,
#   5,
#   16,
#   16,
#   7,
#   16,
#   17,
#   8,
#   17,
#   18,
#   6,
#   18],
#  [9, 7, 9, 10, 2, 10, 11, 5, 11, 13, 8, 13, 15, 7, 15, 16, 7, 16, 18, 6, 18],
#  [9, 7, 9, 10, 2, 10, 12, 3, 12, 13, 3, 13, 15, 1, 15, 16, 4, 16, 18, 5, 18],
#  [9,
#   7,
#   9,
#   11,
#   3,
#   11,
#   12,
#   1,
#   12,
#   13,
#   6,
#   13,
#   14,
#   2,
#   14,
#   15,
#   3,
#   15,
#   16,
#   1,
#   16,
#   17,
#   8,
#   17],
#  [9,
#   7,
#   9,
#   10,
#   2,
#   10,
#   12,
#   2,
#   12,
#   13,
#   8,
#   13,
#   14,
#   1,
#   14,
#   15,
#   7,
#   15,
#   16,
#   5,
#   16,
#   18,
#   7,
#   18],
#  [10, 2, 10, 11, 3, 11, 12, 1, 12, 13, 4, 13, 14, 2, 14, 16, 4, 16, 18, 7, 18],
#  [9,
#   7,
#   9,
#   10,
#   2,
#   10,
#   11,
#   3,
#   11,
#   12,
#   2,
#   12,
#   14,
#   1,
#   14,
#   15,
#   3,
#   15,
#   17,
#   8,
#   17,
#   18,
#   5,
#   18],
#  [11, 5, 11, 12, 2, 12, 13, 6, 13, 14, 1, 14, 15, 3, 15, 16, 1, 16, 18, 4, 18],
#  [9, 7, 9, 10, 2, 10, 12, 3, 12, 13, 3, 13, 14, 2, 14, 16, 7, 16, 17, 8, 17],
#  [10, 2, 10, 11, 8, 11, 12, 3, 12, 13, 6, 13, 15, 1, 15, 16, 4, 16, 18, 5, 18],
#  [12,
#   2,
#   12,
#   13,
#   8,
#   13,
#   14,
#   4,
#   14,
#   15,
#   6,
#   15,
#   16,
#   1,
#   16,
#   17,
#   7,
#   17,
#   17,
#   8,
#   17,
#   18,
#   4,
#   18,
#   18,
#   7,
#   18],
#  [9,
#   7,
#   9,
#   10,
#   2,
#   10,
#   11,
#   7,
#   11,
#   12,
#   2,
#   12,
#   13,
#   8,
#   13,
#   14,
#   2,
#   14,
#   15,
#   1,
#   15,
#   17,
#   6,
#   17],
#  [9,
#   7,
#   9,
#   10,
#   2,
#   10,
#   12,
#   2,
#   12,
#   13,
#   8,
#   13,
#   14,
#   1,
#   14,
#   16,
#   7,
#   16,
#   17,
#   1,
#   17,
#   18,
#   6,
#   18],
#  [9, 7, 9, 13, 6, 13, 14, 7, 14, 15, 6, 15, 16, 7, 16, 17, 8, 17, 18, 4, 18],
#  [9, 7, 9, 10, 2, 10, 11, 7, 11, 12, 3, 12, 13, 8, 13, 14, 2, 14, 17, 5, 17],
#  [9, 7, 9, 10, 2, 10, 11, 3, 11, 13, 3, 13, 14, 1, 14, 16, 7, 16, 18, 6, 18],
#  [9, 7, 9, 10, 2, 10, 11, 5, 11, 12, 3, 12, 13, 8, 13, 15, 6, 15, 17, 8, 17],
#  [9, 7, 9, 10, 2, 10, 11, 3, 11, 14, 8, 14, 15, 6, 15, 16, 5, 16, 16, 5, 16],
#  [9,
#   7,
#   9,
#   10,
#   2,
#   10,
#   10,
#   7,
#   10,
#   12,
#   3,
#   12,
#   13,
#   8,
#   13,
#   14,
#   2,
#   14,
#   16,
#   7,
#   16,
#   17,
#   5,
#   17],
#  [9,
#   7,
#   9,
#   11,
#   3,
#   11,
#   12,
#   1,
#   12,
#   13,
#   8,
#   13,
#   14,
#   8,
#   14,
#   15,
#   3,
#   15,
#   16,
#   1,
#   16,
#   17,
#   8,
#   17],
#  [9, 7, 9, 10, 2, 10, 10, 2, 10, 11, 8, 11, 12, 7, 12, 13, 3, 13, 14, 7, 14],
#  [10, 2, 10, 11, 3, 11, 12, 3, 12, 13, 6, 13, 16, 1, 16, 17, 1, 17, 18, 6, 18],
#  [9, 7, 9, 11, 3, 11, 12, 2, 12, 14, 2, 14, 15, 3, 15, 16, 7, 16, 17, 8, 17],
#  [9, 7, 9, 10, 2, 10, 11, 7, 11, 13, 8, 13, 14, 2, 14, 15, 1, 15, 16, 1, 16],
#  [9, 7, 9, 10, 2, 10, 11, 3, 11, 12, 7, 12, 13, 8, 13, 14, 2, 14, 18, 6, 18],
#  [10, 2, 10, 11, 4, 11, 12, 4, 12, 13, 1, 13, 14, 6, 14, 15, 2, 15, 17, 6, 17],
#  [9,
#   8,
#   9,
#   10,
#   2,
#   10,
#   11,
#   7,
#   11,
#   12,
#   8,
#   12,
#   13,
#   1,
#   13,
#   14,
#   2,
#   14,
#   16,
#   7,
#   16,
#   17,
#   7,
#   17],
#  [9,
#   8,
#   9,
#   10,
#   2,
#   10,
#   11,
#   3,
#   11,
#   12,
#   1,
#   12,
#   14,
#   7,
#   14,
#   15,
#   3,
#   15,
#   16,
#   4,
#   16,
#   17,
#   7,
#   17,
#   18,
#   4,
#   18],
#  [9,
#   8,
#   9,
#   11,
#   8,
#   11,
#   12,
#   1,
#   12,
#   13,
#   5,
#   13,
#   14,
#   7,
#   14,
#   15,
#   3,
#   15,
#   16,
#   5,
#   16,
#   17,
#   6,
#   17,
#   18,
#   4,
#   18],
#  [9,
#   8,
#   9,
#   11,
#   4,
#   11,
#   12,
#   1,
#   12,
#   13,
#   5,
#   13,
#   14,
#   6,
#   14,
#   15,
#   6,
#   15,
#   16,
#   4,
#   16,
#   17,
#   8,
#   17],
#  [9, 8, 9, 10, 2, 10, 11, 7, 11, 12, 2, 12, 14, 2, 14, 16, 5, 16, 17, 1, 17],
#  [9, 8, 9, 10, 2, 10, 11, 8, 11, 12, 4, 12, 15, 2, 15, 17, 6, 17, 18, 6, 18],
#  [9,
#   8,
#   9,
#   10,
#   2,
#   10,
#   11,
#   4,
#   11,
#   11,
#   8,
#   11,
#   12,
#   2,
#   12,
#   12,
#   8,
#   12,
#   13,
#   5,
#   13,
#   13,
#   6,
#   13,
#   16,
#   5,
#   16],
#  [10,
#   2,
#   10,
#   11,
#   7,
#   11,
#   12,
#   8,
#   12,
#   13,
#   6,
#   13,
#   14,
#   2,
#   14,
#   15,
#   5,
#   15,
#   16,
#   4,
#   16,
#   17,
#   1,
#   17,
#   18,
#   4,
#   18],
#  [11, 7, 11, 12, 4, 12, 12, 8, 12, 13, 5, 13, 14, 6, 14, 15, 2, 15, 17, 1, 17],
#  [10, 2, 10, 11, 8, 11, 12, 1, 12, 12, 8, 12, 13, 7, 13, 14, 6, 14, 18, 4, 18],
#  [11,
#   4,
#   11,
#   12,
#   8,
#   12,
#   13,
#   6,
#   13,
#   14,
#   2,
#   14,
#   15,
#   6,
#   15,
#   16,
#   7,
#   16,
#   17,
#   8,
#   17,
#   18,
#   8,
#   18],
#  [9, 8, 9, 11, 7, 11, 12, 8, 12, 15, 2, 15, 16, 4, 16, 17, 6, 17, 18, 6, 18],
#  [9, 8, 9, 10, 2, 10, 11, 4, 11, 12, 8, 12, 13, 7, 13, 14, 7, 14, 16, 5, 16],
#  [9, 8, 9, 10, 2, 10, 11, 7, 11, 13, 5, 13, 14, 4, 14, 16, 5, 16, 18, 4, 18],
#  [10,
#   2,
#   10,
#   11,
#   7,
#   11,
#   11,
#   8,
#   11,
#   12,
#   4,
#   12,
#   13,
#   1,
#   13,
#   14,
#   2,
#   14,
#   16,
#   8,
#   16,
#   17,
#   7,
#   17,
#   18,
#   8,
#   18],
#  [9,
#   8,
#   9,
#   10,
#   2,
#   10,
#   11,
#   4,
#   11,
#   12,
#   8,
#   12,
#   13,
#   1,
#   13,
#   13,
#   5,
#   13,
#   14,
#   2,
#   14,
#   14,
#   4,
#   14],
#  [9, 5, 9, 10, 3, 10, 11, 3, 11, 14, 8, 14, 16, 3, 16, 16, 7, 16, 17, 7, 17],
#  [9, 1, 9, 10, 3, 10, 11, 1, 11, 13, 2, 13, 14, 7, 14, 15, 7, 15, 16, 6, 16],
#  [11, 4, 11, 13, 3, 13, 13, 4, 13, 14, 1, 14, 14, 6, 14, 15, 7, 15, 16, 2, 16],
#  [9, 1, 9, 10, 3, 10, 11, 6, 11, 12, 7, 12, 13, 1, 13, 15, 1, 15, 17, 5, 17],
#  [10, 3, 10, 12, 7, 12, 13, 4, 13, 14, 6, 14, 16, 5, 16, 17, 8, 17, 18, 2, 18],
#  [10,
#   3,
#   10,
#   11,
#   7,
#   11,
#   12,
#   6,
#   12,
#   13,
#   4,
#   13,
#   14,
#   3,
#   14,
#   16,
#   2,
#   16,
#   17,
#   8,
#   17,
#   18,
#   7,
#   18],
#  [10,
#   3,
#   10,
#   11,
#   6,
#   11,
#   12,
#   7,
#   12,
#   13,
#   7,
#   13,
#   14,
#   7,
#   14,
#   15,
#   1,
#   15,
#   16,
#   2,
#   16,
#   17,
#   4,
#   17],
#  [9,
#   5,
#   9,
#   10,
#   4,
#   10,
#   11,
#   4,
#   11,
#   12,
#   5,
#   12,
#   12,
#   8,
#   12,
#   14,
#   1,
#   14,
#   14,
#   1,
# ...
#  [9,
#   5,
#   9,
#   10,
#   4,
#   10,
#   11,
#   6,
#   11,
#   12,
#   4,
#   12,
#   13,
#   5,
#   13,
#   14,
#   3,
#   14,
#   17,
#   2,
#   17,
#   18,
#   3,
#   18],
#  [10, 4, 10, 11, 4, 11, 12, 3, 12, 13, 4, 13, 15, 5, 15, 16, 5, 16, 17, 2, 17],
#  [10,
#   4,
#   10,
#   10,
#   4,
#   10,
#   11,
#   4,
#   11,
#   12,
#   3,
#   12,
#   12,
#   5,
#   12,
#   13,
#   3,
#   13,
#   13,
#   5,
#   13,
#   14,
#   3,
#   14,
#   15,
#   5,
#   15],
#  [9, 5, 9, 10, 4, 10, 11, 6, 11, 12, 5, 12, 15, 5, 15, 17, 2, 17, 18, 8, 18],
#  [9,
#   5,
#   9,
#   11,
#   8,
#   11,
#   12,
#   8,
#   12,
#   13,
#   5,
#   13,
#   14,
#   3,
#   14,
#   17,
#   1,
#   17,
#   17,
#   8,
#   17,
#   18,
#   7,
#   18],
#  [10, 4, 10, 11, 8, 11, 12, 4, 12, 13, 3, 13, 14, 2, 14, 15, 3, 15, 16, 5, 16],
#  [9, 4, 9, 10, 5, 10, 12, 2, 12, 12, 2, 12, 13, 5, 13, 14, 6, 14, 15, 7, 15],
#  [9, 5, 9, 10, 4, 10, 13, 5, 13, 14, 2, 14, 15, 6, 15, 17, 1, 17, 18, 7, 18],
#  [9, 5, 9, 10, 4, 10, 11, 8, 11, 13, 3, 13, 14, 4, 14, 15, 5, 15, 18, 8, 18],
#  [9, 5, 9, 10, 4, 10, 11, 4, 11, 13, 5, 13, 14, 3, 14, 17, 5, 17, 18, 1, 18],
#  [10,
#   4,
#   10,
#   11,
#   3,
#   11,
#   12,
#   4,
#   12,
#   13,
#   4,
#   13,
#   14,
#   4,
#   14,
#   15,
#   3,
#   15,
#   16,
#   1,
#   16,
#   18,
#   8,
#   18],
#  [9,
#   6,
#   9,
#   11,
#   8,
#   11,
#   12,
#   3,
#   12,
#   13,
#   3,
#   13,
#   14,
#   7,
#   14,
#   15,
#   7,
#   15,
#   16,
#   7,
#   16,
#   17,
#   5,
#   17],
#  [9,
#   6,
#   9,
#   10,
#   4,
#   10,
#   12,
#   3,
#   12,
#   13,
#   2,
#   13,
#   14,
#   6,
#   14,
#   16,
#   7,
#   16,
#   17,
#   5,
#   17,
#   18,
#   1,
#   18],
#  [10, 4, 10, 11, 8, 11, 12, 5, 12, 13, 1, 13, 14, 6, 14, 15, 2, 15, 16, 7, 16],
#  [9, 6, 9, 11, 8, 11, 12, 5, 12, 13, 3, 13, 14, 6, 14, 15, 2, 15, 17, 2, 17],
#  [9, 6, 9, 12, 3, 12, 13, 3, 13, 14, 2, 14, 15, 7, 15, 16, 2, 16, 17, 5, 17],
#  [9,
#   6,
#   9,
#   12,
#   3,
#   12,
#   13,
#   1,
#   13,
#   13,
#   8,
#   13,
#   14,
#   1,
#   14,
#   15,
#   6,
#   15,
#   16,
#   8,
#   16,
#   16,
#   8,
#   16,
#   17,
#   6,
#   17],
#  [10, 4, 10, 11, 2, 11, 12, 5, 12, 13, 8, 13, 14, 6, 14, 15, 8, 15, 17, 2, 17],
#  [11, 2, 11, 12, 1, 12, 13, 2, 13, 14, 1, 14, 15, 7, 15, 16, 8, 16, 17, 5, 17],
#  [9, 6, 9, 10, 4, 10, 11, 6, 11, 12, 1, 12, 13, 8, 13, 14, 2, 14, 17, 3, 17],
#  [9,
#   6,
#   9,
#   10,
#   4,
#   10,
#   11,
#   6,
#   11,
#   12,
#   1,
#   12,
#   13,
#   1,
#   13,
#   14,
#   6,
#   14,
#   15,
#   2,
#   15,
#   17,
#   3,
#   17,
#   18,
#   1,
#   18],
#  [11, 8, 11, 12, 5, 12, 13, 1, 13, 14, 7, 14, 15, 8, 15, 17, 5, 17, 18, 7, 18],
#  [9, 6, 9, 10, 4, 10, 11, 8, 11, 12, 4, 12, 13, 1, 13, 14, 1, 14, 17, 6, 17],
#  [10, 4, 10, 11, 4, 11, 13, 3, 13, 13, 3, 13, 14, 1, 14, 14, 2, 14, 17, 6, 17],
#  [9,
#   6,
#   9,
#   10,
#   4,
#   10,
#   12,
#   5,
#   12,
#   13,
#   3,
#   13,
#   15,
#   6,
#   15,
#   16,
#   1,
#   16,
#   17,
#   2,
#   17,
#   18,
#   2,
#   18],
#  [9,
#   6,
#   9,
#   10,
#   4,
#   10,
#   10,
#   4,
#   10,
#   11,
#   6,
#   11,
#   12,
#   3,
#   12,
#   12,
#   5,
#   12,
#   13,
#   1,
#   13,
#   14,
#   2,
#   14,
#   17,
#   2,
#   17,
#   18,
#   4,
#   18],
#  [11, 8, 11, 12, 3, 12, 13, 8, 13, 14, 1, 14, 15, 8, 15, 16, 2, 16, 16, 7, 16],
#  [9, 6, 9, 10, 4, 10, 11, 8, 11, 12, 3, 12, 13, 8, 13, 17, 5, 17, 18, 1, 18],
#  [9,
#   6,
#   9,
#   10,
#   4,
#   10,
#   11,
#   4,
#   11,
#   12,
#   5,
#   12,
#   13,
#   1,
#   13,
#   14,
#   2,
#   14,
#   16,
#   7,
#   16,
#   17,
#   2,
#   17],
#  [9,
#   6,
#   9,
#   10,
#   4,
#   10,
#   11,
#   4,
#   11,
#   12,
#   3,
#   12,
#   13,
#   1,
#   13,
#   14,
#   6,
#   14,
#   16,
#   8,
#   16,
#   18,
#   6,
#   18],
#  [9, 7, 9, 11, 5, 11, 12, 8, 12, 14, 8, 14, 15, 5, 15, 16, 8, 16, 18, 8, 18],
#  [9, 7, 9, 10, 4, 10, 11, 8, 11, 12, 8, 12, 13, 6, 13, 15, 2, 15, 18, 8, 18],
#  [9, 7, 9, 10, 4, 10, 11, 1, 11, 11, 5, 11, 11, 5, 11, 12, 6, 12, 13, 2, 13],
#  [10,
#   4,
#   10,
#   11,
#   8,
#   11,
#   12,
#   2,
#   12,
#   12,
#   8,
#   12,
#   13,
#   2,
#   13,
#   13,
#   3,
#   13,
#   14,
#   1,
#   14,
#   16,
#   1,
#   16],
#  [9, 7, 9, 10, 4, 10, 11, 5, 11, 15, 8, 15, 16, 1, 16, 17, 4, 17, 18, 2, 18],
#  [11, 8, 11, 12, 2, 12, 13, 2, 13, 14, 8, 14, 15, 5, 15, 17, 4, 17, 18, 7, 18],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   1,
#   11,
#   12,
#   6,
#   12,
#   13,
#   8,
#   13,
#   16,
#   4,
#   16,
#   17,
#   8,
#   17,
#   18,
#   7,
#   18],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   1,
#   11,
#   12,
#   8,
#   12,
#   13,
#   6,
#   13,
#   13,
#   8,
#   13,
#   14,
#   1,
#   14,
#   14,
#   7,
#   14,
#   15,
#   6,
#   15],
#  [9, 7, 9, 10, 4, 10, 12, 2, 12, 13, 2, 13, 14, 1, 14, 15, 8, 15, 16, 4, 16],
#  [11, 5, 11, 12, 8, 12, 13, 3, 13, 14, 1, 14, 14, 8, 14, 15, 5, 15, 15, 6, 15],
#  [9, 7, 9, 12, 8, 12, 13, 8, 13, 14, 3, 14, 15, 6, 15, 17, 4, 17, 18, 8, 18],
#  [9, 7, 9, 10, 4, 10, 11, 1, 11, 12, 6, 12, 13, 3, 13, 14, 8, 14, 15, 2, 15],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   3,
#   11,
#   13,
#   8,
#   13,
#   14,
#   8,
#   14,
#   16,
#   1,
#   16,
#   17,
#   4,
#   17,
#   18,
#   7,
#   18],
#  [9, 7, 9, 10, 4, 10, 11, 1, 11, 13, 8, 13, 15, 2, 15, 16, 4, 16, 18, 7, 18],
#  [9, 7, 9, 12, 6, 12, 13, 2, 13, 13, 3, 13, 14, 7, 14, 14, 8, 14, 18, 2, 18],
#  [10,
#   4,
#   10,
#   11,
#   1,
#   11,
#   11,
#   3,
#   11,
#   12,
#   6,
#   12,
#   13,
#   6,
#   13,
#   15,
#   5,
#   15,
#   16,
#   4,
#   16,
#   18,
#   8,
#   18],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   5,
#   11,
#   13,
#   6,
#   13,
#   14,
#   3,
#   14,
#   16,
#   4,
#   16,
#   17,
#   5,
#   17,
#   18,
#   5,
#   18],
#  [9,
#   7,
#   9,
#   11,
#   1,
#   11,
#   13,
#   6,
#   13,
#   13,
#   8,
#   13,
#   14,
#   1,
#   14,
#   14,
#   1,
#   14,
#   15,
#   6,
#   15,
#   16,
#   4,
#   16,
#   16,
#   7,
#   16,
#   18,
#   5,
#   18],
#  [9,
#   7,
#   9,
#   11,
#   1,
#   11,
#   11,
#   3,
#   11,
#   12,
#   2,
#   12,
#   14,
#   1,
#   14,
#   15,
#   5,
#   15,
#   15,
#   5,
#   15,
#   16,
#   7,
#   16,
#   18,
#   2,
#   18],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   3,
#   11,
#   12,
#   6,
#   12,
#   13,
#   8,
#   13,
#   14,
#   3,
#   14,
#   15,
#   5,
#   15,
#   16,
#   8,
#   16,
#   17,
#   7,
#   17],
#  [10,
#   4,
#   10,
#   11,
#   3,
#   11,
#   12,
#   8,
#   12,
#   13,
#   6,
#   13,
#   14,
#   8,
#   14,
#   15,
#   8,
#   15,
#   16,
#   1,
#   16,
#   17,
#   4,
#   17,
#   18,
#   5,
#   18],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   3,
#   11,
#   12,
#   6,
#   12,
#   12,
#   7,
#   12,
#   13,
#   6,
#   13,
#   14,
#   7,
#   14,
#   15,
#   8,
#   15,
#   17,
#   4,
#   17],
#  [10,
#   4,
#   10,
#   11,
#   5,
#   11,
#   12,
#   8,
#   12,
#   13,
#   2,
#   13,
#   14,
#   8,
#   14,
#   16,
#   4,
#   16,
#   17,
#   4,
#   17,
#   18,
#   8,
#   18],
#  [9, 7, 9, 10, 4, 10, 11, 8, 11, 12, 8, 12, 13, 6, 13, 17, 8, 17, 18, 7, 18],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   8,
#   11,
#   12,
#   2,
#   12,
#   13,
#   3,
#   13,
#   13,
#   3,
#   13,
#   14,
#   1,
#   14,
#   15,
#   5,
#   15,
#   15,
#   6,
#   15,
#   16,
#   4,
#   16],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   1,
#   11,
#   11,
#   3,
#   11,
#   12,
#   8,
#   12,
#   13,
#   6,
#   13,
#   14,
#   7,
#   14,
#   15,
#   2,
#   15],
#  [10, 4, 10, 11, 1, 11, 12, 6, 12, 13, 8, 13, 14, 3, 14, 15, 6, 15, 18, 8, 18],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   1,
#   11,
#   11,
#   1,
#   11,
#   12,
#   8,
#   12,
#   13,
#   2,
#   13,
#   14,
#   3,
#   14,
#   15,
#   8,
#   15,
#   17,
#   7,
#   17,
#   18,
#   2,
#   18],
#  [10, 4, 10, 11, 3, 11, 11, 3, 11, 12, 8, 12, 13, 2, 13, 15, 2, 15, 16, 1, 16],
#  [9, 7, 9, 9, 7, 9, 10, 4, 10, 10, 4, 10, 11, 3, 11, 11, 8, 11, 12, 2, 12],
#  [9, 7, 9, 10, 4, 10, 10, 4, 10, 10, 8, 10, 11, 4, 11, 13, 7, 13, 17, 5, 17],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   5,
#   11,
#   12,
#   7,
#   12,
#   13,
#   8,
#   13,
#   15,
#   5,
#   15,
#   17,
#   7,
#   17,
#   18,
#   8,
#   18],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   1,
#   11,
#   13,
#   6,
#   13,
#   14,
#   8,
#   14,
#   15,
#   6,
#   15,
#   16,
#   8,
#   16,
#   18,
#   5,
#   18],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   5,
#   11,
#   13,
#   6,
#   13,
#   15,
#   5,
#   15,
#   16,
#   1,
#   16,
#   17,
#   7,
#   17,
#   18,
#   7,
#   18],
#  [10,
#   4,
#   10,
#   11,
#   5,
#   11,
#   12,
#   7,
#   12,
#   13,
#   6,
#   13,
#   14,
#   7,
#   14,
#   15,
#   8,
#   15,
#   16,
#   8,
#   16,
#   17,
#   8,
#   17],
#  [10,
#   4,
#   10,
#   11,
#   5,
#   11,
#   12,
#   8,
#   12,
#   13,
#   3,
#   13,
#   14,
#   7,
#   14,
#   16,
#   4,
#   16,
#   17,
#   7,
#   17,
#   17,
#   8,
#   17,
#   18,
#   2,
#   18],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   3,
#   11,
#   12,
#   2,
#   12,
#   13,
#   3,
#   13,
#   14,
#   7,
#   14,
#   16,
#   7,
#   16,
#   17,
#   5,
#   17,
#   18,
#   5,
#   18],
#  [9, 7, 9, 10, 4, 10, 11, 5, 11, 12, 7, 12, 14, 1, 14, 16, 1, 16, 17, 7, 17],
#  [10,
#   4,
#   10,
#   11,
#   8,
#   11,
#   12,
#   6,
#   12,
#   13,
#   2,
#   13,
#   14,
#   8,
#   14,
#   15,
#   6,
#   15,
#   17,
#   4,
#   17,
#   18,
#   5,
#   18],
#  [9,
#   7,
#   9,
#   11,
#   1,
#   11,
#   13,
#   8,
#   13,
#   14,
#   1,
#   14,
#   15,
#   5,
#   15,
#   16,
#   4,
#   16,
#   17,
#   7,
#   17,
#   18,
#   2,
#   18],
#  [9,
#   7,
#   9,
#   10,
#   4,
#   10,
#   11,
#   5,
#   11,
#   13,
#   8,
#   13,
#   14,
#   8,
#   14,
#   15,
#   2,
#   15,
#   16,
#   7,
#   16,
#   17,
#   8,
#   17],
#  [12, 2, 12, 13, 2, 13, 13, 3, 13, 14, 7, 14, 16, 8, 16, 17, 7, 17, 18, 2, 18],
#  [9,
#   7,
#   9,
#   11,
#   3,
#   11,
#   13,
#   3,
#   13,
#   13,
#   6,
#   13,
#   14,
#   1,
#   14,
#   15,
#   8,
#   15,
#   15,
#   8,
#   15,
#   16,
#   7,
#   16],
#  [9, 7, 9, 10, 4, 10, 11, 5, 11, 13, 3, 13, 14, 3, 14, 15, 2, 15, 16, 7, 16],
#  [10, 4, 10, 11, 2, 11, 12, 2, 12, 14, 2, 14, 15, 2, 15, 17, 6, 17, 18, 7, 18],
#  [9,
#   8,
#   9,
#   10,
#   4,
#   10,
#   10,
#   4,
#   10,
#   11,
#   7,
#   11,
#   12,
#   2,
#   12,
#   14,
#   3,
#   14,
#   15,
#   2,
#   15,
#   18,
#   3,
#   18],
#  [10, 4, 10, 11, 2, 11, 12, 4, 12, 14, 1, 14, 15, 2, 15, 16, 4, 16, 18, 3, 18],
#  [10,
#   4,
#   10,
#   10,
#   5,
#   10,
#   12,
#   6,
#   12,
#   13,
#   2,
#   13,
#   13,
#   4,
#   13,
#   14,
#   1,
#   14,
#   15,
#   3,
#   15,
#   18,
#   3,
#   18,
#   18,
#   4,
#   18],
#  [9,
#   8,
#   9,
#   10,
#   4,
#   10,
#   12,
#   4,
#   12,
#   13,
#   5,
#   13,
#   14,
#   1,
#   14,
#   15,
#   6,
#   15,
#   17,
#   6,
#   17,
#   18,
#   5,
#   18],
#  [10, 4, 10, 13, 5, 13, 14, 5, 14, 15, 2, 15, 16, 4, 16, 17, 6, 17, 18, 5, 18],
#  [10, 4, 10, 11, 6, 11, 12, 3, 12, 13, 3, 13, 14, 2, 14, 15, 3, 15, 17, 6, 17],
#  [9,
#   8,
#   9,
#   10,
#   4,
#   10,
#   11,
#   7,
#   11,
#   13,
#   5,
#   13,
#   15,
#   2,
#   15,
#   16,
#   1,
#   16,
#   17,
#   5,
#   17,
#   18,
#   5,
#   18],
#  [9,
#   8,
#   9,
#   11,
#   5,
#   11,
#   12,
#   2,
#   12,
#   13,
#   3,
#   13,
#   14,
#   1,
#   14,
#   14,
#   1,
#   14,
#   15,
#   7,
#   15,
#   15,
#   7,
#   15,
#   16,
#   2,
#   16,
#   16,
#   6,
#   16,
#   18,
#   5,
#   18],
#  [9, 8, 9, 10, 4, 10, 11, 2, 11, 12, 4, 12, 13, 4, 13, 14, 3, 14, 16, 2, 16],
#  [9, 8, 9, 11, 5, 11, 13, 4, 13, 14, 2, 14, 16, 2, 16, 17, 6, 17, 18, 8, 18],
#  [11, 5, 11, 11, 7, 11, 12, 4, 12, 13, 5, 13, 14, 1, 14, 16, 6, 16, 17, 6, 17],
#  [9,
#   8,
#   9,
#   10,
#   4,
#   10,
#   12,
#   4,
#   12,
#   14,
#   5,
#   14,
#   15,
#   6,
#   15,
#   16,
#   4,
#   16,
#   17,
#   3,
#   17,
#   18,
#   7,
#   18],
#  [9,
#   8,
#   9,
#   10,
#   4,
#   10,
#   11,
#   2,
#   11,
#   12,
#   2,
#   12,
#   14,
#   1,
#   14,
#   14,
#   3,
#   14,
#   15,
#   2,
#   15,
#   16,
#   1,
#   16,
#   17,
#   5,
#   17],
#  [11, 5, 11, 12, 2, 12, 13, 3, 13, 14, 1, 14, 16, 2, 16, 17, 6, 17, 18, 7, 18],
#  [9,
#   8,
#   9,
#   10,
#   4,
#   10,
#   11,
#   2,
#   11,
#   12,
#   3,
#   12,
#   13,
#   2,
#   13,
#   14,
#   2,
#   14,
#   15,
#   6,
#   15,
#   17,
#   4,
#   17],
#  [9, 8, 9, 10, 4, 10, 11, 4, 11, 14, 2, 14, 15, 2, 15, 17, 5, 17, 18, 5, 18],
#  [9, 8, 9, 10, 4, 10, 11, 5, 11, 12, 7, 12, 15, 2, 15, 16, 2, 16, 17, 6, 17],
#  [10,
#   4,
#   10,
#   11,
#   7,
#   11,
#   12,
#   4,
#   12,
#   13,
#   3,
#   13,
#   14,
#   1,
#   14,
#   15,
#   2,
#   15,
#   17,
#   4,
#   17,
#   18,
#   7,
#   18],
#  [12, 3, 12, 12, 4, 12, 13, 3, 13, 15, 2, 15, 16, 4, 16, 17, 6, 17, 18, 3, 18],
#  [9,
#   8,
#   9,
#   10,
#   4,
#   10,
#   11,
#   2,
#   11,
#   12,
#   4,
#   12,
#   13,
#   3,
#   13,
#   15,
#   7,
#   15,
#   16,
#   1,
#   16,
#   17,
#   6,
#   17],
#  [9,
#   8,
#   9,
#   10,
#   4,
#   10,
#   11,
#   6,
#   11,
#   12,
#   2,
#   12,
#   15,
#   2,
#   15,
#   16,
#   2,
#   16,
#   17,
#   3,
#   17,
#   17,
#   6,
#   17],
#  [9,
#   8,
#   9,
#   11,
#   6,
#   11,
#   12,
#   7,
#   12,
#   13,
#   3,
#   13,
#   13,
#   4,
#   13,
#   13,
#   5,
#   13,
#   14,
#   1,
#   14,
#   15,
#   6,
#   15,
#   16,
#   4,
#   16],
#  [9,
#   8,
#   9,
#   10,
#   4,
#   10,
#   11,
#   2,
#   11,
#   13,
#   5,
#   13,
#   14,
#   3,
#   14,
#   15,
#   7,
#   15,
#   17,
#   4,
#   17,
#   18,
#   8,
#   18],
#  [9, 8, 9, 12, 4, 12, 13, 3, 13, 13, 4, 13, 14, 1, 14, 15, 6, 15, 16, 1, 16],
#  [9, 1, 9, 10, 8, 10, 10, 8, 10, 11, 2, 11, 12, 6, 12, 14, 4, 14, 17, 8, 17],
#  [9,
#   8,
#   9,
#   10,
#   4,
#   10,
#   11,
#   6,
#   11,
#   12,
#   2,
#   12,
#   13,
#   5,
#   13,
#   15,
#   6,
#   15,
#   17,
#   3,
#   17,
#   18,
#   5,
#   18],
#  [10,
#   4,
#   10,
#   12,
#   2,
#   12,
#   13,
#   2,
#   13,
#   13,
#   3,
#   13,
#   14,
#   2,
#   14,
#   15,
#   3,
#   15,
#   17,
#   5,
#   17,
#   18,
#   3,
#   18],
#  [10, 4, 10, 11, 7, 11, 12, 4, 12, 13, 3, 13, 14, 5, 14, 17, 3, 17, 18, 8, 18],
#  [9,
#   8,
#   9,
#   10,
#   4,
#   10,
#   11,
#   6,
#   11,
#   12,
#   4,
#   12,
#   13,
#   2,
#   13,
#   13,
#   3,
#   13,
#   14,
#   3,
#   14,
#   16,
#   4,
#   16],
#  [9, 8, 9, 10, 4, 10, 11, 7, 11, 12, 7, 12, 13, 2, 13, 15, 7, 15, 16, 6, 16],
#  [11, 5, 11, 12, 7, 12, 13, 2, 13, 14, 5, 14, 15, 3, 15, 16, 6, 16, 17, 5, 17],
#  [9,
#   8,
#   9,
#   10,
#   4,
#   10,
#   11,
#   6,
#   11,
#   13,
#   5,
#   13,
#   15,
#   2,
#   15,
#   16,
#   1,
#   16,
#   16,
#   2,
#   16,
#   16,
#   2,
#   16,
#   17,
#   3,
#   17,
#   18,
#   3,
#   18],
#  [9,
#   8,
#   9,
#   10,
#   4,
#   10,
#   11,
#   2,
#   11,
#   12,
#   4,
#   12,
#   12,
#   4,
#   12,
#   13,
#   2,
#   13,
#   14,
#   1,
#   14,
#   15,
#   7,
#   15,
#   16,
#   4,
#   16],
#  [11, 2, 11, 12, 4, 12, 13, 4, 13, 15, 6, 15, 16, 2, 16, 17, 3, 17, 18, 7, 18],
#  [9, 8, 9, 11, 6, 11, 12, 3, 12, 13, 3, 13, 14, 3, 14, 17, 3, 17, 18, 7, 18],
#  [9,
#   1,
#   9,
#   10,
#   5,
#   10,
#   11,
#   1,
#   11,
#   12,
#   2,
#   12,
#   12,
#   6,
#   12,
#   13,
#   5,
#   13,
#   13,
#   8,
#   13,
#   14,
#   2,
#   14,
#   14,
#   4,
#   14],
#  [10,
#   5,
#   10,
#   11,
#   1,
#   11,
#   12,
#   5,
#   12,
#   13,
#   2,
#   13,
#   14,
#   3,
#   14,
#   15,
#   8,
#   15,
#   17,
#   2,
#   17,
#   18,
#   4,
#   18],
#  [9,
#   1,
#   9,
#   10,
#   5,
#   10,
#   12,
#   5,
#   12,
#   13,
#   3,
#   13,
#   14,
#   6,
#   14,
#   15,
#   3,
#   15,
#   16,
#   7,
#   16,
#   18,
#   2,
#   18],
#  [9, 1, 9, 10, 5, 10, 11, 6, 11, 12, 5, 12, 12, 7, 12, 13, 2, 13, 15, 6, 15],
#  [9, 1, 9, 10, 5, 10, 11, 4, 11, 13, 8, 13, 14, 2, 14, 15, 8, 15, 18, 2, 18],
#  [10, 5, 10, 11, 1, 11, 12, 2, 12, 14, 4, 14, 16, 7, 16, 17, 3, 17, 18, 2, 18],
#  [10, 5, 10, 11, 3, 11, 13, 2, 13, 14, 4, 14, 16, 7, 16, 17, 5, 17, 18, 7, 18],
#  [9,
#   1,
#   9,
#   10,
#   6,
#   10,
#   11,
#   4,
#   11,
#   12,
#   4,
#   12,
#   13,
#   8,
#   13,
#   13,
#   8,
#   13,
#   14,
#   4,
#   14,
#   15,
#   5,
#   15],
#  [9, 1, 9, 10, 5, 10, 11, 6, 11, 15, 3, 15, 16, 7, 16, 17, 5, 17, 18, 2, 18],
#  [9,
#   1,
#   9,
#   10,
#   5,
#   10,
#   11,
#   4,
#   11,
#   14,
#   2,
#   14,
#   14,
#   3,
#   14,
#   15,
#   3,
#   15,
#   17,
#   4,
#   17,
#   18,
#   7,
#   18],
#  [10,
#   5,
#   10,
#   11,
#   1,
#   11,
#   12,
#   2,
#   12,
#   13,
#   2,
#   13,
#   14,
#   6,
#   14,
#   15,
#   5,
#   15,
#   16,
#   1,
#   16,
#   18,
#   4,
#   18],
#  [9,
#   1,
#   9,
#   10,
#   5,
#   10,
#   11,
#   6,
#   11,
#   12,
#   2,
#   12,
#   14,
#   4,
#   14,
#   15,
#   3,
#   15,
#   16,
#   5,
#   16,
#   18,
#   2,
#   18],
#  [10,
#   5,
#   10,
#   12,
#   5,
#   12,
#   13,
#   5,
#   13,
#   13,
#   8,
#   13,
#   14,
#   6,
#   14,
#   14,
#   6,
#   14,
#   15,
#   3,
#   15,
#   15,
#   3,
#   15],
#  [13,
#   2,
#   13,
#   13,
#   3,
#   13,
#   14,
#   3,
#   14,
#   14,
#   3,
#   14,
#   15,
#   3,
#   15,
#   15,
#   5,
#   15,
#   16,
#   5,
#   16,
#   17,
#   4,
#   17,
#   18,
#   8,
#   18],
#  [9, 1, 9, 10, 5, 10, 11, 1, 11, 12, 2, 12, 13, 8, 13, 14, 4, 14, 18, 2, 18],
#  [9, 1, 9, 10, 5, 10, 13, 5, 13, 14, 6, 14, 15, 5, 15, 17, 2, 17, 18, 8, 18],
#  [9, 1, 9, 11, 1, 11, 13, 5, 13, 14, 4, 14, 15, 8, 15, 17, 4, 17, 18, 2, 18],
#  [9,
#   1,
#   9,
#   9,
#   1,
#   9,
#   10,
#   5,
#   10,
#   11,
#   4,
#   11,
#   11,
#   4,
#   11,
#   12,
#   5,
#   12,
#   13,
#   3,
#   13,
#   13,
#   8,
#   13,
#   15,
#   6,
#   15,
#   17,
#   3,
#   17,
#   17,
#   5,
#   17],
#  [9,
#   1,
#   9,
#   11,
#   3,
#   11,
#   12,
#   6,
#   12,
#   13,
#   2,
#   13,
#   15,
#   5,
#   15,
#   16,
#   5,
#   16,
#   17,
#   2,
#   17,
#   18,
#   7,
#   18],
#  [9,
#   1,
#   9,
#   11,
#   6,
#   11,
#   12,
#   2,
#   12,
#   13,
#   3,
#   13,
#   14,
#   3,
#   14,
#   16,
#   1,
#   16,
#   17,
#   3,
#   17,
#   18,
#   7,
#   18],
#  [9,
#   1,
#   9,
#   10,
#   5,
#   10,
#   11,
#   6,
#   11,
#   12,
#   6,
#   12,
#   13,
#   3,
#   13,
#   14,
#   3,
#   14,
#   15,
#   8,
#   15,
#   16,
#   7,
#   16,
#   17,
#   4,
#   17],
#  [9, 1, 9, 10, 5, 10, 11, 4, 11, 12, 5, 12, 13, 5, 13, 14, 3, 14, 15, 5, 15],
#  [9,
#   1,
#   9,
#   10,
#   5,
#   10,
#   11,
#   4,
#   11,
#   13,
#   2,
#   13,
#   14,
#   6,
#   14,
#   15,
#   5,
#   15,
#   17,
#   5,
#   17,
#   18,
#   7,
#   18],
#  [9, 1, 9, 10, 5, 10, 12, 6, 12, 13, 8, 13, 15, 6, 15, 16, 5, 16, 17, 4, 17],
#  [11, 1, 11, 12, 6, 12, 13, 3, 13, 14, 3, 14, 15, 3, 15, 16, 7, 16, 17, 5, 17],
#  [9,
#   1,
#   9,
#   10,
#   5,
#   10,
#   11,
#   6,
#   11,
#   13,
#   5,
#   13,
#   14,
#   2,
#   14,
#   14,
#   2,
#   14,
#   14,
#   6,
#   14,
#   16,
#   1,
#   16],
#  [9,
#   1,
#   9,
#   10,
#   5,
#   10,
#   12,
#   2,
#   12,
#   12,
#   6,
#   12,
#   13,
#   8,
#   13,
#   14,
#   3,
#   14,
#   14,
#   6,
#   14,
#   15,
#   6,
#   15],
#  [9,
#   1,
#   9,
#   10,
#   5,
#   10,
#   11,
#   3,
#   11,
#   13,
#   3,
#   13,
#   14,
#   3,
#   14,
#   14,
#   4,
#   14,
#   15,
#   3,
#   15,
#   17,
#   2,
#   17],
#  [9, 1, 9, 10, 5, 10, 13, 5, 13, 14, 6, 14, 16, 1, 16, 17, 4, 17, 18, 2, 18],
#  [9, 1, 9, 10, 5, 10, 11, 4, 11, 12, 2, 12, 13, 5, 13, 15, 6, 15, 17, 2, 17],
#  [9, 1, 9, 11, 6, 11, 13, 3, 13, 14, 4, 14, 15, 3, 15, 16, 1, 16, 18, 2, 18],
#  [10, 5, 10, 12, 3, 12, 13, 4, 13, 15, 6, 15, 16, 8, 16, 17, 3, 17, 18, 3, 18],
#  [9, 2, 9, 10, 5, 10, 11, 8, 11, 14, 3, 14, 15, 6, 15, 16, 3, 16, 18, 3, 18],
#  [10, 5, 10, 13, 5, 13, 14, 5, 14, 15, 4, 15, 16, 8, 16, 17, 7, 17, 18, 1, 18],
#  ...]

# %% [markdown]
# Unique spacers for each cycle - assigning both types of spacers to the same type - it should have enough data to classify it anyway. However, there is a lot of space for ambiguity so the ground truth might be useful. Anyway, let's put this on and see what happens.

# %%
empirical_train_df_spacers['Spacer_Sequence'] = spacer_sequences

# %%
empirical_train_df_spacers.head()
# Out:
#    ONT_Barcode                     HW_Address  \
# 0            1  barcode_external01_internal01
# 1            1  barcode_external01_internal01
# 2            1  barcode_external01_internal01
# 3            1  barcode_external01_internal01
# 4            1  barcode_external01_internal01
#
#                                              Payload  \
# 0  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 1  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 2  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 3  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 4  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
#
#                                       Library_Motifs  \
# 0  ['ltm8_2x1', 'ltm8_3x3', 'ltm8_3x5', 'ltm8_4x1...
# 1  ['ltm8_3x5', 'ltm8_4x1', 'ltm8_4x1', 'ltm8_6x7...
# 2  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_4x2', 'ltm8_5x7...
# 3  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_2x1', 'ltm8_3x4...
# 4  ['ltm8_1x1', 'ltm8_3x2', 'ltm8_4x2', 'ltm8_5x1...
#
#                                 read_id  \
# 0  0804c886-cd0a-4ece-87ee-adb529974699
# 1  0f041c54-7071-49d3-8ae2-7a1bf25525ab
# 2  1361a5db-d135-4e98-bb49-7a53c8d72991
# 3  1b4284d2-bee2-4a15-abab-aad861447308
# 4  1cc7b7bb-cd90-485f-b744-cf846d566675
#
#                                             squiggle  \
# 0  [0.7250000000000001, 0.7350000000000001, 0.752...
# 1  [0.525, 0.4845238095238096, 0.5035714285714287...
# 2  [0.6675799086757991, 0.5095890410958903, 0.515...
# 3  [0.6846153846153846, 0.5461538461538461, 0.549...
# 4  [0.7113163972286374, 0.6628175519630484, 0.662...
#
#                         Motifs  \
# 0        [1, 3, 5, 1, 1, 4, 5]
# 1        [5, 1, 1, 7, 7, 7, 8]
# 2     [1, 1, 2, 7, 4, 5, 6, 5]
# 3        [1, 1, 1, 4, 4, 6, 6]
# 4  [1, 2, 2, 1, 4, 8, 3, 3, 5]
#
#                                      Spacer_Sequence
# 0  [10, 1, 10, 11, 3, 11, 11, 5, 11, 12, 1, 12, 1...
# 1  [11, 5, 11, 12, 1, 12, 12, 1, 12, 14, 7, 14, 1...
# 2  [9, 1, 9, 10, 1, 10, 12, 2, 12, 13, 7, 13, 14,...
# 3  [9, 1, 9, 10, 1, 10, 10, 1, 10, 11, 4, 11, 13,...
# 4  [9, 1, 9, 11, 2, 11, 12, 2, 12, 13, 1, 13, 14,...

# %%
empirical_train_df_spacers.to_pickle("datasets\empirical\empirical_train_dataset_v4_spacers.pkl")

# %% [markdown]
# ### Load and verify integrity of data

# %%
empirical_train_df_spacers = pd.read_pickle("datasets\empirical\empirical_train_dataset_v4_spacers.pkl")

# %%
empirical_train_df_spacers.head()
# Out:
#    ONT_Barcode                     HW_Address  \
# 0            1  barcode_external01_internal01
# 1            1  barcode_external01_internal01
# 2            1  barcode_external01_internal01
# 3            1  barcode_external01_internal01
# 4            1  barcode_external01_internal01
#
#                                              Payload  \
# 0  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 1  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 2  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 3  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
# 4  [[2, 3, 4, 5], [1, 2, 7, 8], [1, 4, 5, 6], [4,...
#
#                                       Library_Motifs  \
# 0  ['ltm8_2x1', 'ltm8_3x3', 'ltm8_3x5', 'ltm8_4x1...
# 1  ['ltm8_3x5', 'ltm8_4x1', 'ltm8_4x1', 'ltm8_6x7...
# 2  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_4x2', 'ltm8_5x7...
# 3  ['ltm8_1x1', 'ltm8_2x1', 'ltm8_2x1', 'ltm8_3x4...
# 4  ['ltm8_1x1', 'ltm8_3x2', 'ltm8_4x2', 'ltm8_5x1...
#
#                                 read_id  \
# 0  0804c886-cd0a-4ece-87ee-adb529974699
# 1  0f041c54-7071-49d3-8ae2-7a1bf25525ab
# 2  1361a5db-d135-4e98-bb49-7a53c8d72991
# 3  1b4284d2-bee2-4a15-abab-aad861447308
# 4  1cc7b7bb-cd90-485f-b744-cf846d566675
#
#                                             squiggle  \
# 0  [0.7250000000000001, 0.7350000000000001, 0.752...
# 1  [0.525, 0.4845238095238096, 0.5035714285714287...
# 2  [0.6675799086757991, 0.5095890410958903, 0.515...
# 3  [0.6846153846153846, 0.5461538461538461, 0.549...
# 4  [0.7113163972286374, 0.6628175519630484, 0.662...
#
#                         Motifs  \
# 0        [1, 3, 5, 1, 1, 4, 5]
# 1        [5, 1, 1, 7, 7, 7, 8]
# 2     [1, 1, 2, 7, 4, 5, 6, 5]
# 3        [1, 1, 1, 4, 4, 6, 6]
# 4  [1, 2, 2, 1, 4, 8, 3, 3, 5]
#
#                                      Spacer_Sequence
# 0  [10, 1, 10, 11, 3, 11, 11, 5, 11, 12, 1, 12, 1...
# 1  [11, 5, 11, 12, 1, 12, 12, 1, 12, 14, 7, 14, 1...
# 2  [9, 1, 9, 10, 1, 10, 12, 2, 12, 13, 7, 13, 14,...
# 3  [9, 1, 9, 10, 1, 10, 10, 1, 10, 11, 4, 11, 13,...
# 4  [9, 1, 9, 11, 2, 11, 12, 2, 12, 13, 1, 13, 14,...
